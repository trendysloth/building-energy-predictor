# %% [markdown]
# ### Load data from S3

# %%
import boto3
import pandas as pd
from sagemaker import get_execution_role

train_data_location = ''
test_data_location = ''
submission_location = ''

# %%
import joblib

# %%
df_train = pd.read_csv(train_data_location)
df_test = pd.read_csv(test_data_location)
df_submission = pd.read_csv(submission_location)

# %%
df_test.shape, df_submission.shape
# Out:
# ((41697600, 19), (24936697, 2))

# %%
# from pandas.tseries.holiday import USFederalHolidayCalendar
# cal = USFederalHolidayCalendar()
# holidays = cal.holidays(start='2016-01-01', end='2018-12-31').to_pydatetime()
# print(holidays)

# %%
df_train['timestamp']=pd.to_datetime(df_train['timestamp'])
df_test['timestamp']=pd.to_datetime(df_test['timestamp'])
# df_submission=pd.to_datetime(df_submission['timestamp'])

# %%
def preprocess(df):
    df["hour"] = df["timestamp"].dt.hour
#     df["day"] = df["timestamp"].dt.day
    df["weekend"] = df["timestamp"].dt.weekday
    df["month"] = df["timestamp"].dt.month
    df["dayofweek"] = df["timestamp"].dt.dayofweek

# %%
preprocess(df_train)
preprocess(df_test)

# %%
# df_train['is_holiday'] = df_train.apply(lambda row: row.timestamp in holidays, axis = 1)
# df_test['is_holiday'] = df_test.apply(lambda row: row.timestamp in holidays, axis = 1)

# %%
df_train = df_train.drop(['Unnamed: 0'], axis=1)
df_test = df_test.drop(['Unnamed: 0'], axis=1)
# df_submission = df_submission.drop(['Unnamed: 0'], axis=1)

# %%
# x_submit = df_test[['building_id', 'meter', 'site_id', 'primary_use', 'square_feet', 'month', 'day', 'hour']]

# %%
# submission = pd.read_csv('data/test_submission_full.csv')

# %%
# submission.head()

# %%
# df_test.timestamp

# %% [markdown]
# ### Filter missing value entries

# %%
filter_variables = [
    'air_temperature', 'dew_temperature', 'precip_depth_1_hr', 
    'sea_level_pressure', 'wind_direction', 'wind_speed'
]

# %%
# Filter out zeros
def filter_by_columns(df, variables):
    for var in variables:
        df = df[df[var].notnull()]
    return df

# %%
df_train = filter_by_columns(df_train, df_train.columns)

# %%
import numpy as np
def describe_stats_by_uses(train):
    usages = df_train['primary_use'].unique()
    df = {'primary_use': [], 'meter_reading_mean': [], 'meter_reading_std': []}
    df = pd.DataFrame(data=df)
    mean = []
    std = []
#     print(usages)
    for use in usages:
#         print(use)
        df_filter = train[train.primary_use == use]
#         print(df_filter.head())
        mean.append(np.mean(df_filter['meter_reading']))
        std.append(np.std(df_filter['meter_reading']))
    df['primary_use'] = usages
    df['meter_reading_mean'] = mean
    df['meter_reading_std'] = std
    return df

# %%
df_meter_reading_by_usage = describe_stats_by_uses(df_train)

# %%
df_meter_reading_by_usage
# Out:
#                       primary_use  meter_reading_mean  meter_reading_std
# 0                       Education         6410.346163      288503.022712
# 1             Lodging/residential          327.948961        1133.527547
# 2                          Office          606.529602        3688.813310
# 3   Entertainment/public assembly          540.230224       11645.436617
# 4                           Other          143.073003         458.542699
# 5                          Retail          170.388693         367.559422
# 6                         Parking          172.075026         693.211104
# 7                 Public services          305.621619        1284.002356
# 8               Warehouse/storage           54.393144          66.802817
# 9          Food sales and service          305.341700         570.281145
# 10              Religious worship            3.969560           3.101675
# 11                     Healthcare          764.286871        1386.096818
# 12                        Utility          634.306124         803.768303
# 13             Technology/science          134.744648         248.018141
# 14                       Services         4715.030703       15621.874757
# 15       Manufacturing/industrial          322.756190         533.493546

# %% [markdown]
# ### Train / Val / Test Split

# %%
from sklearn import preprocessing
from sklearn.preprocessing import OneHotEncoder, LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold

# %%
df_train.shape
# Out:
# (14963318, 20)

# %%
# train, test 80/20 split with weather information
# x_train, x_test, y_train, y_test = train_test_split(df_train[['meter', 'site_id', 'primary_use', 
#                                                               'air_temperature', 'dew_temperature', 
#                                                               'precip_depth_1_hr', 'sea_level_pressure',
#                                                               'wind_direction', 'wind_speed']], 
#                                                     df_train['meter_reading'],
#                                                     test_size = 0.2,
#                                                     shuffle = True)

# %%
df_train.columns
# Out:
# Index(['building_id', 'meter', 'timestamp', 'meter_reading', 'site_id',
#        'primary_use', 'square_feet', 'air_temperature', 'dew_temperature',
#        'precip_depth_1_hr', 'sea_level_pressure', 'wind_direction',
#        'wind_speed', 'beaufort_scale', 'year', 'month', 'day', 'hour',
#        'weekend', 'dayofweek'],
#       dtype='object')

# %%
print(len(df_train['building_id'].unique()))
print(len(df_train['site_id'].unique()))
print(len(df_train['primary_use'].unique()))
print(len(df_train['meter'].unique()))
print(len(df_train['wind_direction'].unique()))
# Out:
# 1273
# 13
# 16
# 4
# 37

# %%
def preprocess_datetime(df):
    df["hour"] = df["timestamp"].dt.hour
#     df["day"] = df["timestamp"].dt.day
    df["weekend"] = df["timestamp"].dt.weekday
    df["month"] = df["timestamp"].dt.month
    df["dayofweek"] = df["timestamp"].dt.dayofweek
    hour_rad = df["hour"].values / 24. * 2 * np.pi
    df["hour_sin"] = np.sin(hour_rad)
    df["hour_cos"] = np.cos(hour_rad)

# %%
preprocess_datetime(df_train)
preprocess_datetime(df_test)

# %%
df_train.columns
# Out:
# Index(['building_id', 'meter', 'timestamp', 'meter_reading', 'site_id',
#        'primary_use', 'square_feet', 'air_temperature', 'dew_temperature',
#        'precip_depth_1_hr', 'sea_level_pressure', 'wind_direction',
#        'wind_speed', 'beaufort_scale', 'year', 'month', 'day', 'hour',
#        'weekend', 'dayofweek', 'hour_sin', 'hour_cos'],
#       dtype='object')

# %%
# df_train['dayofweek']

# %%
numericals = [
    'square_feet', 
    'beaufort_scale',
    'precip_depth_1_hr',
    'dew_temperature',
    'air_temperature',
    'hour_sin', 
    'hour_cos',
    'sea_level_pressure',
    'wind_direction',
    'wind_speed',
#     'building_id',
#     'site_id'
]

# %%
categoricals = [
#     'building_id',
    'site_id', 
    'primary_use', 
#     'month',
#     'hour', 
#     'day', 
    'meter',  
    'month',
#     'weekend', 
    'dayofweek'
#     'wind_direction'
]

# %%
feat_cols = numericals + categoricals

# %%
# df_train.head()

# %%
# print(len(df_train['building_id'].unique()))
# print(len(df_train['site_id'].unique()))
# print(len(df_train['primary_use'].unique()))
# print(len(df_train['meter'].unique()))
# print(len(df_train['wind_direction'].unique()))

# %%
# df_train['wind_direction']

# %%
# feat_cols = categoricals + numericals

# %%
for category in categoricals:
    df_train[category] = df_train[category].astype('category')
    df_test[category] = df_test[category].astype('category')
#     df_submission[category] = df_submission[category].astype('category')

# %%
# df_train['meter'] = to_categorical(df_train['meter'])

# %%
# df_train_categorical = df_train[categoricals]

# %%
# df_train_categorical.columns

# %%
df_train = pd.get_dummies(df_train)
df_test = pd.get_dummies(df_test)
# df_submission = pd.get_dummies(df_submission)

# %%
# feat_cols_dummies = df_train.columns

# %%
# feat_cols += [
#     'meter_0', 'meter_1', 'meter_2',
#     'meter_3', 'site_id_0', 'site_id_2', 'site_id_3', 'site_id_4',
#     'site_id_6', 'site_id_7', 'site_id_8', 'site_id_9', 'site_id_10',
#     'site_id_11', 'site_id_13', 'site_id_14', 'site_id_15',
#     'primary_use_Education', 'primary_use_Entertainment/public assembly',
#     'primary_use_Food sales and service', 'primary_use_Healthcare',
#     'primary_use_Lodging/residential',
#     'primary_use_Manufacturing/industrial', 'primary_use_Office',
#     'primary_use_Other', 'primary_use_Parking',
#     'primary_use_Public services', 'primary_use_Religious worship',
#     'primary_use_Retail', 'primary_use_Services',
#     'primary_use_Technology/science', 'primary_use_Utility',
#     'primary_use_Warehouse/storage'
# ]

# %%
df_train.columns
# Out:
# Index(['building_id', 'timestamp', 'meter_reading', 'square_feet',
#        'air_temperature', 'dew_temperature', 'precip_depth_1_hr',
#        'sea_level_pressure', 'wind_direction', 'wind_speed', 'beaufort_scale',
#        'year', 'day', 'hour', 'weekend', 'hour_sin', 'hour_cos', 'meter_0',
#        'meter_1', 'meter_2', 'meter_3', 'site_id_0', 'site_id_2', 'site_id_3',
#        'site_id_4', 'site_id_6', 'site_id_7', 'site_id_8', 'site_id_9',
#        'site_id_10', 'site_id_11', 'site_id_13', 'site_id_14', 'site_id_15',
#        'primary_use_Education', 'primary_use_Entertainment/public assembly',
#        'primary_use_Food sales and service', 'primary_use_Healthcare',
#        'primary_use_Lodging/residential',
#        'primary_use_Manufacturing/industrial', 'primary_use_Office',
#        'primary_use_Other', 'primary_use_Parking',
#        'primary_use_Public services', 'primary_use_Religious worship',
#        'primary_use_Retail', 'primary_use_Services',
#        'primary_use_Technology/science', 'primary_use_Utility',
#        'primary_use_Warehouse/storage', 'month_1', 'month_2', 'month_3',
#        'month_4', 'month_5', 'month_6', 'month_7', 'month_8', 'month_9',
#        'month_10', 'month_11', 'month_12', 'dayofweek_0', 'dayofweek_1',
#        'dayofweek_2', 'dayofweek_3', 'dayofweek_4', 'dayofweek_5',
#        'dayofweek_6'],
#       dtype='object')

# %%
feat_cols = numericals + [
    'meter_0', 'meter_1', 'meter_2', 'meter_3', 
    'site_id_0', 'site_id_2', 'site_id_3', 'site_id_4', 'site_id_6', 'site_id_7', 'site_id_8', 'site_id_9',
    'site_id_10', 'site_id_11', 'site_id_13', 'site_id_14', 'site_id_15',
    'primary_use_Education', 'primary_use_Entertainment/public assembly',
    'primary_use_Food sales and service', 'primary_use_Healthcare',
    'primary_use_Lodging/residential',
    'primary_use_Manufacturing/industrial', 'primary_use_Office',
    'primary_use_Other', 'primary_use_Parking',
    'primary_use_Public services', 'primary_use_Religious worship',
    'primary_use_Retail', 'primary_use_Services',
    'primary_use_Technology/science', 'primary_use_Utility',
    'primary_use_Warehouse/storage', 'month_1', 'month_2', 'month_3',
    'month_4', 'month_5', 'month_6', 'month_7', 'month_8', 'month_9',
    'month_10', 'month_11', 'month_12', 'dayofweek_0', 'dayofweek_1',
    'dayofweek_2', 'dayofweek_3', 'dayofweek_4', 'dayofweek_5',
    'dayofweek_6'
]

# %%
feat_cols
# Out:
# ['square_feet',
#  'beaufort_scale',
#  'precip_depth_1_hr',
#  'dew_temperature',
#  'air_temperature',
#  'hour_sin',
#  'hour_cos',
#  'sea_level_pressure',
#  'wind_direction',
#  'wind_speed',
#  'meter_0',
#  'meter_1',
#  'meter_2',
#  'meter_3',
#  'site_id_0',
#  'site_id_2',
#  'site_id_3',
#  'site_id_4',
#  'site_id_6',
#  'site_id_7',
#  'site_id_8',
#  'site_id_9',
#  'site_id_10',
#  'site_id_11',
#  'site_id_13',
#  'site_id_14',
#  'site_id_15',
#  'primary_use_Education',
#  'primary_use_Entertainment/public assembly',
#  'primary_use_Food sales and service',
#  'primary_use_Healthcare',
#  'primary_use_Lodging/residential',
#  'primary_use_Manufacturing/industrial',
#  'primary_use_Office',
#  'primary_use_Other',
#  'primary_use_Parking',
#  'primary_use_Public services',
#  'primary_use_Religious worship',
#  'primary_use_Retail',
#  'primary_use_Services',
#  'primary_use_Technology/science',
#  'primary_use_Utility',
#  'primary_use_Warehouse/storage',
#  'month_1',
#  'month_2',
#  'month_3',
#  'month_4',
#  'month_5',
#  'month_6',
#  'month_7',
#  'month_8',
#  'month_9',
#  'month_10',
#  'month_11',
#  'month_12',
#  'dayofweek_0',
#  'dayofweek_1',
#  'dayofweek_2',
#  'dayofweek_3',
#  'dayofweek_4',
#  'dayofweek_5',
#  'dayofweek_6']

# %%
# # # train, test 80/20 split without weather information
x_train, x_test, y_train, y_test = train_test_split(df_train[feat_cols], 
                                                    df_train['meter_reading'],
                                                    test_size = 0.2,
                                                    shuffle = True)

# %%
x_submit = df_test[feat_cols]

# %%
# x_train['hour'] = np.cos(x_train['hour'])
# x_test['hour'] = np.cos(x_test['hour'])
# x_submit['hour'] = np.cos(x_submit['hour'])

# %%
# one-hot encoding for categorical variables
# label_encoder = preprocessing.LabelEncoder()
# x_train['primary_use'] = label_encoder.fit_transform(x_train['primary_use'])
# x_test['primary_use'] = label_encoder.fit_transform(x_test['primary_use'])
# x_submit['primary_use'] = label_encoder.fit_transform(x_submit['primary_use'])

# %%
x_train.columns
# Out:
# Index(['square_feet', 'beaufort_scale', 'precip_depth_1_hr', 'dew_temperature',
#        'air_temperature', 'hour_sin', 'hour_cos', 'sea_level_pressure',
#        'wind_direction', 'wind_speed', 'meter_0', 'meter_1', 'meter_2',
#        'meter_3', 'site_id_0', 'site_id_2', 'site_id_3', 'site_id_4',
#        'site_id_6', 'site_id_7', 'site_id_8', 'site_id_9', 'site_id_10',
#        'site_id_11', 'site_id_13', 'site_id_14', 'site_id_15',
#        'primary_use_Education', 'primary_use_Entertainment/public assembly',
#        'primary_use_Food sales and service', 'primary_use_Healthcare',
#        'primary_use_Lodging/residential',
#        'primary_use_Manufacturing/industrial', 'primary_use_Office',
#        'primary_use_Other', 'primary_use_Parking',
#        'primary_use_Public services', 'primary_use_Religious worship',
#        'primary_use_Retail', 'primary_use_Services',
#        'primary_use_Technology/science', 'primary_use_Utility',
#        'primary_use_Warehouse/storage', 'month_1', 'month_2', 'month_3',
#        'month_4', 'month_5', 'month_6', 'month_7', 'month_8', 'month_9',
#        'month_10', 'month_11', 'month_12', 'dayofweek_0', 'dayofweek_1',
#        'dayofweek_2', 'dayofweek_3', 'dayofweek_4', 'dayofweek_5',
#        'dayofweek_6'],
#       dtype='object')

# %%
# x_train['primary_use']

# %%
# standardization
#     'square_feet', 
#     'beaufort_scale',
#     'precip_depth_1_hr',
#     'dew_temperature',
#     'air_temperature',
#     'month',
#     'hour',
#     'day', 
#     'sea_level_pressure',
#     'wind_direction',
#     'wind_speed'
    
numerical_standardize = ['square_feet', 'precip_depth_1_hr', 'dew_temperature', 
                         'air_temperature', 
                         'sea_level_pressure', 'wind_direction', 'wind_speed']
standard_scaler = preprocessing.StandardScaler().fit(x_train[numerical_standardize])
x_train[numerical_standardize] = standard_scaler.transform(x_train[numerical_standardize])
x_test[numerical_standardize] = standard_scaler.transform(x_test[numerical_standardize])
x_submit[numerical_standardize] = standard_scaler.transform(x_submit[numerical_standardize])
# standard_scaler = preprocessing.StandardScaler().fit(x_submit)
# x_submit = standard_scaler.transform(x_submit)
# Out:
# /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/ipykernel/__main__.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/pandas/core/indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
# train, validation 80/20 split
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size = 0.2, shuffle = True)

# %%
x_train.shape, x_val.shape, x_test.shape
# , x_submit.shape
# Out:
# ((9576523, 62), (2394131, 62), (2992664, 62))

# %%
# x_train[numericals]

# %% [markdown]
# ### Evaluation metric (RMSLE)

# %%
import math

# Function to calculate Root Mean Squared Logarithmic Error (RMSLE)
def rmsle(y, y_pred):
    assert len(y) == len(y_pred)
    terms_to_sum = [(math.log(y_pred[i] + 1) - math.log(y[i] + 1)) ** 2.0 for i, pred in enumerate(y_pred)]
    return (sum(terms_to_sum) * (1.0/len(y))) ** 0.5

# %% [markdown]
# ### Baseline (Linear Regression)

# %%
from sklearn.linear_model import RidgeCV
from sklearn.linear_model import LassoCV

# %%
clf = RidgeCV(alphas=[1e-3, 1e-2, 1e-1, 1, 10, 100]).fit(x_val, y_val.values)
y_pred_lr = clf.predict(x_test)

# %%
y_pred_lr[y_pred_lr < 0] = 0

# %%
baseline_rmsle = rmsle(list(y_test), list(y_pred_lr))

# %%
print('Ridge Regression RMSLE Score is {}'.format(baseline_rmsle))
# Out:
# Ridge Regression RMSLE Score is 4.583467525689335

# %%
lasso = LassoCV(alphas=[1e-3, 1e-2, 1e-1, 1, 10, 100]).fit(x_val, y_val.values)
y_pred_lr = lasso.predict(x_test)
# Out:
# /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/sklearn/model_selection/_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 951085014820568.0, tolerance: 7349363503107.383
#   positive)

# %%
y_pred_lr[y_pred_lr < 0] = 0

# %%
Lasso_rmsle = rmsle(list(y_test), list(y_pred_lr))

# %%
print('Lasso Regression RMSLE Score is {}'.format(Lasso_rmsle))
# Out:
# Lasso Regression RMSLE Score is 4.582095287863697

# %% [markdown]
# ### Support Vector Regressor

# %%
from sklearn import svm
from sklearn.svm import LinearSVC, SVC
from sklearn import linear_model

# %%
# Linear Regressor
svr = linear_model.SGDRegressor(early_stopping=True, validation_fraction=0.2)
svr.fit(x_train, y_train.values)
# Out:
# SGDRegressor(alpha=0.0001, average=False, early_stopping=True, epsilon=0.1,
#              eta0=0.01, fit_intercept=True, l1_ratio=0.15,
#              learning_rate='invscaling', loss='squared_loss', max_iter=1000,
#              n_iter_no_change=5, penalty='l2', power_t=0.25, random_state=None,
#              shuffle=True, tol=0.001, validation_fraction=0.2, verbose=0,
#              warm_start=False)

# %%
y_pred_svr = svr.predict(x_test)
y_pred_svr[y_pred_svr < 0] = 0

# %%
svr_rmsle = rmsle(list(y_test), list(y_pred_svr))

# %%
print('SGDRegressor RMSLE Score is {}'.format(svr_rmsle))
# Out:
# SGDRegressor RMSLE Score is 4.692523335534162

# %% [markdown]
# ### xgboost

# %%
# !pip install xgboost
# Out:
# Collecting xgboost
#   Downloading https://files.pythonhosted.org/packages/c1/24/5fe7237b2eca13ee0cfb100bec8c23f4e69ce9df852a64b0493d49dae4e0/xgboost-0.90-py2.py3-none-manylinux1_x86_64.whl (142.8MB)
#     100% |████████████████████████████████| 142.8MB 340kB/s eta 0:00:01
# Requirement already satisfied: numpy in /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages (from xgboost) (1.16.4)
# Requirement already satisfied: scipy in /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages (from xgboost) (1.3.1)
# Installing collected packages: xgboost
# Successfully installed xgboost-0.90
# You are using pip version 10.0.1, however version 19.3.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
from numpy import loadtxt
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
import xgboost as xgb

# %%
from sklearn.model_selection import GridSearchCV

# %%
# xgb_model = XGBClassifier(
#     objective='reg:squarederror', 
#     silent=True, 
#     eval_metric='merror'
# )
# test_params = {
#     'learning_rate': [0.01, 0.1],
#     'max_depth': [2, 3, 4], 
#     'min_child_weight': [1, 2, 3]
# }
# model = GridSearchCV(estimator = xgb_model, param_grid = test_params, cv=5)
# # x_cv = get_feature_layer(cnn_model, x_comb_train)
# # y_cv = y_comb_train.argmax(axis=1)
# # model.fit(x_cv, y_cv)
# model.fit(x_val, y_val)
# print(model.best_params_)

# %%
dtrain = xgb.DMatrix(x_train, label=y_train)
dval = xgb.DMatrix(x_val, label=y_val)
dtest = xgb.DMatrix(x_test, label=y_test)
# Out:
# /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/xgboost/core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \

# %%
pars = {
    'colsample_bytree': 0.8,                 
    'learning_rate': 0.35,
    'max_depth': 5,
    'subsample': 0.8,
    'objective': 'reg:squarederror',
}

# %%
model = xgb.train(
    pars,
    dtrain,
    num_boost_round=200,
    evals=[(dtrain, 'train'), (dval, 'val')],
    verbose_eval=5,
    early_stopping_rounds=40,
)
# Out:
# [22:40:23] WARNING: /workspace/src/learner.cc:686: Tree method is automatically selected to be 'approx' for faster speed. To use old behavior (exact greedy algorithm on single machine), set tree_method to 'exact'.
# [0]	train-rmse:173139	val-rmse:173545
# Multiple eval metrics have been passed: 'val-rmse' will be used for early stopping.
#
# Will train until val-rmse hasn't improved in 40 rounds.
# [5]	train-rmse:139100	val-rmse:138558
# [10]	train-rmse:116364	val-rmse:115192
# [15]	train-rmse:110288	val-rmse:109069
# [20]	train-rmse:107724	val-rmse:106402
# [25]	train-rmse:104427	val-rmse:103268
# [30]	train-rmse:101386	val-rmse:101109
# [35]	train-rmse:98495	val-rmse:98232.7
# [40]	train-rmse:97237.3	val-rmse:97242.7
# [45]	train-rmse:95827.8	val-rmse:95719.1
# [50]	train-rmse:94696.9	val-rmse:94589.7
# [55]	train-rmse:93187.1	val-rmse:93323.5
# [60]	train-rmse:92896.7	val-rmse:93107.2
# [65]	train-rmse:92096	val-rmse:92426
# [70]	train-rmse:91900.7	val-rmse:92306.9
# [75]	train-rmse:91451.8	val-rmse:91928.4
# [80]	train-rmse:90650	val-rmse:91359.3
# [85]	train-rmse:89088.6	val-rmse:89808
# [90]	train-rmse:88483.7	val-rmse:89294.6
# [95]	train-rmse:88296.3	val-rmse:89186.7
# [100]	train-rmse:87923.9	val-rmse:88853.3
# [105]	train-rmse:87665.1	val-rmse:88641.9
# [110]	train-rmse:86961.8	val-rmse:88420.4
# [115]	train-rmse:86646.1	val-rmse:88084.3
# [120]	train-rmse:86551.7	val-rmse:88028
# [125]	train-rmse:86306.7	val-rmse:87757.9
# [130]	train-rmse:86128.9	val-rmse:87683.4
# [135]	train-rmse:85552.7	val-rmse:87119.8
# [140]	train-rmse:85372.1	val-rmse:86970.5
# [145]	train-rmse:84944.3	val-rmse:86375.4
# [150]	train-rmse:84100.5	val-rmse:85654.7
# [155]	train-rmse:83965.4	val-rmse:85546.4
# [160]	train-rmse:83718.4	val-rmse:85357.5
# [165]	train-rmse:83523.8	val-rmse:85240
# [170]	train-rmse:83298.1	val-rmse:85059.5
# [175]	train-rmse:82885.1	val-rmse:84689.1
# [180]	train-rmse:82717.4	val-rmse:84571.1
# [185]	train-rmse:82574.9	val-rmse:84495.3
# [190]	train-rmse:82227.1	val-rmse:84246.5
# [195]	train-rmse:81566.3	val-rmse:83894.2
# [199]	train-rmse:81525.5	val-rmse:83871.6

# %%
dpredict = model.predict(dtest)

# %%
dpredict[dpredict < 0] = 0

# %%
xgb_rmsle = rmsle(list(y_test), list(dpredict))

# %%
print('XGBoost RMSLE Score is {}'.format(xgb_rmsle))
# Out:
# XGBoost RMSLE Score is 3.630609326250741

# %%
joblib.dump(model, 'xgboost_3.h5')
# Out:
# ['xgboost_3.h5']

# %% [markdown]
# ### lightgbm

# %%
# x_test.head()

# %%
# !pip install lightgbm
# Out:
# Collecting lightgbm
#   Downloading https://files.pythonhosted.org/packages/0b/9d/ddcb2f43aca194987f1a99e27edf41cf9bc39ea750c3371c2a62698c509a/lightgbm-2.3.1-py2.py3-none-manylinux1_x86_64.whl (1.2MB)
#     100% |████████████████████████████████| 1.2MB 22.7MB/s ta 0:00:01
# Requirement already satisfied: numpy in /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages (from lightgbm) (1.16.4)
# Requirement already satisfied: scikit-learn in /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages (from lightgbm) (0.21.3)
# Requirement already satisfied: scipy in /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages (from lightgbm) (1.3.1)
# Requirement already satisfied: joblib>=0.11 in /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages (from scikit-learn->lightgbm) (0.13.2)
# Installing collected packages: lightgbm
# Successfully installed lightgbm-2.3.1
# You are using pip version 10.0.1, however version 19.3.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
import lightgbm as lgb

# %%
# Use small max_bin
# Use small num_leaves
# Use min_data_in_leaf and min_sum_hessian_in_leaf
# Use bagging by set bagging_fraction and bagging_freq
# Use feature sub-sampling by set feature_fraction
# Use bigger training data
# Try lambda_l1, lambda_l2 and min_gain_to_split for regularization
# Try max_depth to avoid growing deep tree

# %% [markdown]
# ### parameter default setting

# %% [markdown]
# boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
# importance_type='split', learning_rate=0.1, max_depth=-1,
# min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
# n_estimators=100, n_jobs=-1, num_leaves=31, objective=None,
# random_state=None, reg_alpha=0.0, reg_lambda=0.0, silent=True,
# subsample=1.0, subsample_for_bin=200000, subsample_freq=0

# %% [markdown]
# ### using a small learning_rate for better accuracy

# %%
params = {
    'boosting_type': 'gbdt',
    'objective': 'regression',
    'metric': {'rmse'},
    'learning_rate': 0.001,
}

# %%
dftrainLGB = lgb.Dataset(data = x_train, label = y_train.values)

# %%
# training with more rounds
cv_results = lgb.cv(
    params,
    dftrainLGB,
    num_boost_round=1000,
    nfold=10,
    early_stopping_rounds=100,
    stratified=False,
    verbose_eval=True
)
# Out:
# [1]	cv_agg's rmse: 177071 + 6944.17
# [2]	cv_agg's rmse: 176989 + 6943.27
# [3]	cv_agg's rmse: 176907 + 6942.37
# [4]	cv_agg's rmse: 176825 + 6941.38
# [5]	cv_agg's rmse: 176744 + 6940.48
# [6]	cv_agg's rmse: 176662 + 6939.49
# [7]	cv_agg's rmse: 176581 + 6938.49
# [8]	cv_agg's rmse: 176499 + 6937.51
# [9]	cv_agg's rmse: 176419 + 6936.6
# [10]	cv_agg's rmse: 176338 + 6935.61
# [11]	cv_agg's rmse: 176257 + 6934.57
# [12]	cv_agg's rmse: 176176 + 6933.57
# [13]	cv_agg's rmse: 176096 + 6932.63
# [14]	cv_agg's rmse: 176015 + 6931.62
# [15]	cv_agg's rmse: 175934 + 6930.77
# [16]	cv_agg's rmse: 175854 + 6929.79
# [17]	cv_agg's rmse: 175774 + 6929.1
# [18]	cv_agg's rmse: 175694 + 6928.3
# [19]	cv_agg's rmse: 175614 + 6927.52
# [20]	cv_agg's rmse: 175534 + 6926.75
# [21]	cv_agg's rmse: 175454 + 6925.45
# [22]	cv_agg's rmse: 175374 + 6924.59
# [23]	cv_agg's rmse: 175294 + 6923.64
# [24]	cv_agg's rmse: 175215 + 6923.03
# [25]	cv_agg's rmse: 175134 + 6921.98
# [26]	cv_agg's rmse: 175056 + 6920.97
# [27]	cv_agg's rmse: 174976 + 6920.16
# [28]	cv_agg's rmse: 174897 + 6919.61
# [29]	cv_agg's rmse: 174818 + 6919
# [30]	cv_agg's rmse: 174739 + 6918.1
# [31]	cv_agg's rmse: 174660 + 6917.14
# [32]	cv_agg's rmse: 174581 + 6916.62
# [33]	cv_agg's rmse: 174502 + 6915.79
# [34]	cv_agg's rmse: 174424 + 6915.25
# [35]	cv_agg's rmse: 174347 + 6914.73
# [36]	cv_agg's rmse: 174269 + 6914.34
# [37]	cv_agg's rmse: 174191 + 6913.77
# [38]	cv_agg's rmse: 174114 + 6913.1
# [39]	cv_agg's rmse: 174037 + 6912.63
# [40]	cv_agg's rmse: 173960 + 6912.09
# [41]	cv_agg's rmse: 173882 + 6911.74
# [42]	cv_agg's rmse: 173805 + 6910.92
# [43]	cv_agg's rmse: 173729 + 6910.76
# [44]	cv_agg's rmse: 173652 + 6910.07
# [45]	cv_agg's rmse: 173576 + 6910.04
# [46]	cv_agg's rmse: 173499 + 6909.11
# [47]	cv_agg's rmse: 173423 + 6908.77
# [48]	cv_agg's rmse: 173347 + 6908.29
# [49]	cv_agg's rmse: 173271 + 6907.62
# [50]	cv_agg's rmse: 173195 + 6907.03
# [51]	cv_agg's rmse: 173119 + 6906.82
# [52]	cv_agg's rmse: 173044 + 6906.55
# [53]	cv_agg's rmse: 172968 + 6906.01
# [54]	cv_agg's rmse: 172893 + 6905.6
# [55]	cv_agg's rmse: 172817 + 6905.51
# [56]	cv_agg's rmse: 172743 + 6904.94
# [57]	cv_agg's rmse: 172668 + 6904.59
# [58]	cv_agg's rmse: 172592 + 6904.04
# [59]	cv_agg's rmse: 172518 + 6903.7
# [60]	cv_agg's rmse: 172443 + 6903.46
# [61]	cv_agg's rmse: 172369 + 6903.11
# [62]	cv_agg's rmse: 172294 + 6902.66
# [63]	cv_agg's rmse: 172220 + 6902.22
# [64]	cv_agg's rmse: 172146 + 6902.12
# [65]	cv_agg's rmse: 172071 + 6901.23
# [66]	cv_agg's rmse: 171998 + 6901.26
# [67]	cv_agg's rmse: 171923 + 6901.02
# [68]	cv_agg's rmse: 171850 + 6901.14
# [69]	cv_agg's rmse: 171776 + 6900.49
# [70]	cv_agg's rmse: 171703 + 6900.09
# [71]	cv_agg's rmse: 171629 + 6899.63
# [72]	cv_agg's rmse: 171555 + 6899.19
# [73]	cv_agg's rmse: 171482 + 6899.12
# [74]	cv_agg's rmse: 171410 + 6899.01
# [75]	cv_agg's rmse: 171336 + 6898.23
# [76]	cv_agg's rmse: 171263 + 6897.37
# [77]	cv_agg's rmse: 171191 + 6897.23
# [78]	cv_agg's rmse: 171118 + 6896.52
# [79]	cv_agg's rmse: 171045 + 6895.67
# [80]	cv_agg's rmse: 170973 + 6896.25
# [81]	cv_agg's rmse: 170900 + 6895.26
# [82]	cv_agg's rmse: 170829 + 6894.75
# [83]	cv_agg's rmse: 170756 + 6894.47
# [84]	cv_agg's rmse: 170685 + 6893.63
# [85]	cv_agg's rmse: 170613 + 6893.14
# [86]	cv_agg's rmse: 170541 + 6892.16
# [87]	cv_agg's rmse: 170470 + 6892.38
# [88]	cv_agg's rmse: 170398 + 6892.02
# [89]	cv_agg's rmse: 170327 + 6891.94
# [90]	cv_agg's rmse: 170256 + 6891.57
# [91]	cv_agg's rmse: 170184 + 6891.92
# [92]	cv_agg's rmse: 170113 + 6891.39
# [93]	cv_agg's rmse: 170041 + 6890.62
# [94]	cv_agg's rmse: 169971 + 6890.31
# [95]	cv_agg's rmse: 169901 + 6890.36
# [96]	cv_agg's rmse: 169829 + 6889.99
# [97]	cv_agg's rmse: 169759 + 6889.88
# [98]	cv_agg's rmse: 169688 + 6890.24
# [99]	cv_agg's rmse: 169618 + 6889.73
# [100]	cv_agg's rmse: 169547 + 6889.08
# [101]	cv_agg's rmse: 169477 + 6889.71
# [102]	cv_agg's rmse: 169406 + 6888.83
# [103]	cv_agg's rmse: 169335 + 6889.79
# [104]	cv_agg's rmse: 169265 + 6888.49
# [105]	cv_agg's rmse: 169196 + 6889.42
# [106]	cv_agg's rmse: 169125 + 6888.67
# [107]	cv_agg's rmse: 169055 + 6889.56
# [108]	cv_agg's rmse: 168986 + 6888.77
# [109]	cv_agg's rmse: 168916 + 6888.81
# [110]	cv_agg's rmse: 168848 + 6888.13
# [111]	cv_agg's rmse: 168778 + 6888.39
# [112]	cv_agg's rmse: 168709 + 6888.04
# [113]	cv_agg's rmse: 168640 + 6887.92
# [114]	cv_agg's rmse: 168571 + 6887.26
# [115]	cv_agg's rmse: 168503 + 6887.84
# [116]	cv_agg's rmse: 168434 + 6887.46
# [117]	cv_agg's rmse: 168365 + 6887.02
# [118]	cv_agg's rmse: 168297 + 6886.53
# [119]	cv_agg's rmse: 168228 + 6886.62
# [120]	cv_agg's rmse: 168160 + 6886.68
# [121]	cv_agg's rmse: 168092 + 6886.42
# [122]	cv_agg's rmse: 168023 + 6885.97
# [123]	cv_agg's rmse: 167955 + 6886.34
# [124]	cv_agg's rmse: 167888 + 6885.68
# [125]	cv_agg's rmse: 167820 + 6885.04
# [126]	cv_agg's rmse: 167753 + 6885.67
# [127]	cv_agg's rmse: 167685 + 6884.39
# [128]	cv_agg's rmse: 167618 + 6884.42
# [129]	cv_agg's rmse: 167550 + 6884.76
# [130]	cv_agg's rmse: 167483 + 6884.22
# [131]	cv_agg's rmse: 167416 + 6883.31
# [132]	cv_agg's rmse: 167349 + 6883.12
# [133]	cv_agg's rmse: 167282 + 6881.89
# [134]	cv_agg's rmse: 167216 + 6880.62
# [135]	cv_agg's rmse: 167149 + 6880.26
# [136]	cv_agg's rmse: 167083 + 6879.58
# [137]	cv_agg's rmse: 167017 + 6879.55
# [138]	cv_agg's rmse: 166951 + 6878.25
# [139]	cv_agg's rmse: 166885 + 6877.97
# [140]	cv_agg's rmse: 166820 + 6877.1
# [141]	cv_agg's rmse: 166754 + 6875.78
# [142]	cv_agg's rmse: 166688 + 6875.41
# [143]	cv_agg's rmse: 166622 + 6874.37
# [144]	cv_agg's rmse: 166557 + 6873.34
# [145]	cv_agg's rmse: 166491 + 6872.45
# [146]	cv_agg's rmse: 166426 + 6871.39
# [147]	cv_agg's rmse: 166361 + 6870.32
# [148]	cv_agg's rmse: 166296 + 6869.03
# [149]	cv_agg's rmse: 166230 + 6868.03
# [150]	cv_agg's rmse: 166166 + 6866.69
# [151]	cv_agg's rmse: 166100 + 6865.5
# [152]	cv_agg's rmse: 166036 + 6864.18
# [153]	cv_agg's rmse: 165972 + 6863.09
# [154]	cv_agg's rmse: 165907 + 6861.86
# [155]	cv_agg's rmse: 165843 + 6860.5
# [156]	cv_agg's rmse: 165778 + 6859.42
# [157]	cv_agg's rmse: 165714 + 6857.72
# [158]	cv_agg's rmse: 165650 + 6857.27
# [159]	cv_agg's rmse: 165585 + 6855.31
# [160]	cv_agg's rmse: 165521 + 6854.32
# [161]	cv_agg's rmse: 165458 + 6853.1
# [162]	cv_agg's rmse: 165394 + 6852.43
# [163]	cv_agg's rmse: 165330 + 6851.25
# [164]	cv_agg's rmse: 165267 + 6849.68
# [165]	cv_agg's rmse: 165203 + 6848.64
# [166]	cv_agg's rmse: 165140 + 6847.65
# [167]	cv_agg's rmse: 165076 + 6846.67
# [168]	cv_agg's rmse: 165012 + 6845.97
# [169]	cv_agg's rmse: 164949 + 6844.77
# [170]	cv_agg's rmse: 164886 + 6843.58
# [171]	cv_agg's rmse: 164823 + 6842.74
# [172]	cv_agg's rmse: 164760 + 6841.35
# [173]	cv_agg's rmse: 164698 + 6841.19
# [174]	cv_agg's rmse: 164634 + 6839.31
# [175]	cv_agg's rmse: 164572 + 6837.83
# [176]	cv_agg's rmse: 164509 + 6837.23
# [177]	cv_agg's rmse: 164446 + 6835.96
# [178]	cv_agg's rmse: 164384 + 6834.71
# [179]	cv_agg's rmse: 164321 + 6833.28
# [180]	cv_agg's rmse: 164259 + 6833
# [181]	cv_agg's rmse: 164198 + 6831.08
# [182]	cv_agg's rmse: 164136 + 6830.47
# [183]	cv_agg's rmse: 164073 + 6829.01
# [184]	cv_agg's rmse: 164012 + 6827.96
# [185]	cv_agg's rmse: 163950 + 6826.26
# [186]	cv_agg's rmse: 163888 + 6825.54
# [187]	cv_agg's rmse: 163827 + 6823.99
# [188]	cv_agg's rmse: 163765 + 6824.43
# [189]	cv_agg's rmse: 163703 + 6822.89
# [190]	cv_agg's rmse: 163642 + 6821.97
# [191]	cv_agg's rmse: 163582 + 6820.74
# [192]	cv_agg's rmse: 163521 + 6819.49
# [193]	cv_agg's rmse: 163461 + 6818
# [194]	cv_agg's rmse: 163400 + 6816.73
# [195]	cv_agg's rmse: 163340 + 6815.5
# [196]	cv_agg's rmse: 163279 + 6814.89
# [197]	cv_agg's rmse: 163218 + 6813.03
# [198]	cv_agg's rmse: 163157 + 6811.89
# [199]	cv_agg's rmse: 163097 + 6811.05
# [200]	cv_agg's rmse: 163035 + 6809.98
# [201]	cv_agg's rmse: 162975 + 6808.24
# [202]	cv_agg's rmse: 162915 + 6806.81
# [203]	cv_agg's rmse: 162855 + 6805.15
# [204]	cv_agg's rmse: 162793 + 6805.12
# [205]	cv_agg's rmse: 162734 + 6803.81
# [206]	cv_agg's rmse: 162674 + 6802.56
# [207]	cv_agg's rmse: 162614 + 6800.72
# [208]	cv_agg's rmse: 162554 + 6799.56
# [209]	cv_agg's rmse: 162494 + 6798.93
# [210]	cv_agg's rmse: 162434 + 6798.19
# [211]	cv_agg's rmse: 162375 + 6796.57
# [212]	cv_agg's rmse: 162315 + 6795
# [213]	cv_agg's rmse: 162256 + 6793.35
# [214]	cv_agg's rmse: 162197 + 6792.1
# [215]	cv_agg's rmse: 162138 + 6790.74
# [216]	cv_agg's rmse: 162079 + 6789.42
# [217]	cv_agg's rmse: 162020 + 6788.22
# [218]	cv_agg's rmse: 161961 + 6786.99
# [219]	cv_agg's rmse: 161902 + 6786.12
# [220]	cv_agg's rmse: 161844 + 6785
# [221]	cv_agg's rmse: 161785 + 6782.77
# [222]	cv_agg's rmse: 161728 + 6780.86
# [223]	cv_agg's rmse: 161669 + 6778.98
# [224]	cv_agg's rmse: 161611 + 6776.99
# [225]	cv_agg's rmse: 161554 + 6774.98
# [226]	cv_agg's rmse: 161495 + 6774.16
# [227]	cv_agg's rmse: 161437 + 6771.99
# [228]	cv_agg's rmse: 161380 + 6770.94
# [229]	cv_agg's rmse: 161322 + 6769.18
# [230]	cv_agg's rmse: 161264 + 6768.53
# [231]	cv_agg's rmse: 161206 + 6766.59
# [232]	cv_agg's rmse: 161149 + 6764.84
# [233]	cv_agg's rmse: 161092 + 6763.56
# [234]	cv_agg's rmse: 161035 + 6761.81
# [235]	cv_agg's rmse: 160976 + 6761.01
# [236]	cv_agg's rmse: 160920 + 6759.67
# [237]	cv_agg's rmse: 160862 + 6757.75
# [238]	cv_agg's rmse: 160806 + 6756
# [239]	cv_agg's rmse: 160749 + 6754.5
# [240]	cv_agg's rmse: 160693 + 6753.18
# [241]	cv_agg's rmse: 160636 + 6752.15
# [242]	cv_agg's rmse: 160579 + 6750.18
# [243]	cv_agg's rmse: 160523 + 6749.65
# [244]	cv_agg's rmse: 160467 + 6747.4
# [245]	cv_agg's rmse: 160410 + 6746.19
# [246]	cv_agg's rmse: 160354 + 6744.44
# [247]	cv_agg's rmse: 160298 + 6744.24
# [248]	cv_agg's rmse: 160242 + 6742.55
# [249]	cv_agg's rmse: 160186 + 6741.51
# [250]	cv_agg's rmse: 160130 + 6740.33
# [251]	cv_agg's rmse: 160074 + 6739.67
# [252]	cv_agg's rmse: 160018 + 6738.01
# [253]	cv_agg's rmse: 159963 + 6736.8
# [254]	cv_agg's rmse: 159907 + 6735.67
# [255]	cv_agg's rmse: 159851 + 6735.51
# [256]	cv_agg's rmse: 159795 + 6734.15
# [257]	cv_agg's rmse: 159741 + 6733.12
# [258]	cv_agg's rmse: 159685 + 6732.17
# [259]	cv_agg's rmse: 159630 + 6732.23
# [260]	cv_agg's rmse: 159575 + 6731.1
# [261]	cv_agg's rmse: 159521 + 6729.73
# [262]	cv_agg's rmse: 159465 + 6728.36
# [263]	cv_agg's rmse: 159410 + 6726.71
# [264]	cv_agg's rmse: 159356 + 6725.69
# [265]	cv_agg's rmse: 159301 + 6724.04
# [266]	cv_agg's rmse: 159246 + 6723.31
# [267]	cv_agg's rmse: 159192 + 6721.9
# [268]	cv_agg's rmse: 159137 + 6721.5
# [269]	cv_agg's rmse: 159083 + 6720.08
# [270]	cv_agg's rmse: 159028 + 6719.92
# [271]	cv_agg's rmse: 158973 + 6718.59
# [272]	cv_agg's rmse: 158919 + 6718.07
# [273]	cv_agg's rmse: 158865 + 6716.53
# [274]	cv_agg's rmse: 158811 + 6715.81
# [275]	cv_agg's rmse: 158756 + 6715.65
# [276]	cv_agg's rmse: 158703 + 6714.04
# [277]	cv_agg's rmse: 158648 + 6713.67
# [278]	cv_agg's rmse: 158594 + 6712.13
# [279]	cv_agg's rmse: 158541 + 6709.74
# [280]	cv_agg's rmse: 158487 + 6709.23
# [281]	cv_agg's rmse: 158434 + 6707.84
# [282]	cv_agg's rmse: 158379 + 6706.69
# [283]	cv_agg's rmse: 158327 + 6705.76
# [284]	cv_agg's rmse: 158272 + 6704.34
# [285]	cv_agg's rmse: 158219 + 6702.33
# [286]	cv_agg's rmse: 158165 + 6701.33
# [287]	cv_agg's rmse: 158113 + 6699.65
# [288]	cv_agg's rmse: 158059 + 6697.83
# [289]	cv_agg's rmse: 158005 + 6697.22
# [290]	cv_agg's rmse: 157953 + 6695.73
# [291]	cv_agg's rmse: 157900 + 6693.56
# [292]	cv_agg's rmse: 157848 + 6691.5
# [293]	cv_agg's rmse: 157794 + 6689.93
# [294]	cv_agg's rmse: 157741 + 6689.45
# [295]	cv_agg's rmse: 157688 + 6687.45
# [296]	cv_agg's rmse: 157636 + 6685.13
# [297]	cv_agg's rmse: 157583 + 6683.19
# [298]	cv_agg's rmse: 157532 + 6682.6
# [299]	cv_agg's rmse: 157479 + 6680.86
# [300]	cv_agg's rmse: 157427 + 6678.92
# [301]	cv_agg's rmse: 157375 + 6677.06
# [302]	cv_agg's rmse: 157323 + 6676.36
# [303]	cv_agg's rmse: 157271 + 6674.52
# [304]	cv_agg's rmse: 157219 + 6673.01
# [305]	cv_agg's rmse: 157168 + 6671.48
# [306]	cv_agg's rmse: 157115 + 6669.32
# [307]	cv_agg's rmse: 157063 + 6667.93
# [308]	cv_agg's rmse: 157011 + 6667.16
# [309]	cv_agg's rmse: 156960 + 6665.1
# [310]	cv_agg's rmse: 156907 + 6663.9
# [311]	cv_agg's rmse: 156856 + 6662.81
# [312]	cv_agg's rmse: 156803 + 6661.6
# [313]	cv_agg's rmse: 156752 + 6659.44
# [314]	cv_agg's rmse: 156701 + 6658.18
# [315]	cv_agg's rmse: 156650 + 6656.35
# [316]	cv_agg's rmse: 156598 + 6655.37
# [317]	cv_agg's rmse: 156546 + 6654.5
# [318]	cv_agg's rmse: 156496 + 6651.9
# [319]	cv_agg's rmse: 156446 + 6650.65
# [320]	cv_agg's rmse: 156393 + 6649.35
# [321]	cv_agg's rmse: 156343 + 6646.84
# [322]	cv_agg's rmse: 156293 + 6645.06
# [323]	cv_agg's rmse: 156241 + 6643.91
# [324]	cv_agg's rmse: 156190 + 6641.83
# [325]	cv_agg's rmse: 156140 + 6641.26
# [326]	cv_agg's rmse: 156089 + 6639.64
# [327]	cv_agg's rmse: 156039 + 6637.23
# [328]	cv_agg's rmse: 155988 + 6635.9
# [329]	cv_agg's rmse: 155938 + 6633.77
# [330]	cv_agg's rmse: 155888 + 6631.15
# [331]	cv_agg's rmse: 155836 + 6629.33
# [332]	cv_agg's rmse: 155787 + 6628.62
# [333]	cv_agg's rmse: 155736 + 6627.46
# [334]	cv_agg's rmse: 155687 + 6625.34
# [335]	cv_agg's rmse: 155637 + 6623.96
# [336]	cv_agg's rmse: 155588 + 6622.49
# [337]	cv_agg's rmse: 155538 + 6620.95
# [338]	cv_agg's rmse: 155487 + 6620.08
# [339]	cv_agg's rmse: 155439 + 6618.54
# [340]	cv_agg's rmse: 155388 + 6617.15
# [341]	cv_agg's rmse: 155339 + 6614.86
# [342]	cv_agg's rmse: 155290 + 6614.21
# [343]	cv_agg's rmse: 155240 + 6612.82
# [344]	cv_agg's rmse: 155190 + 6611.29
# [345]	cv_agg's rmse: 155142 + 6609.44
# [346]	cv_agg's rmse: 155092 + 6608.65
# [347]	cv_agg's rmse: 155042 + 6606.47
# [348]	cv_agg's rmse: 154994 + 6605.08
# [349]	cv_agg's rmse: 154944 + 6603.49
# [350]	cv_agg's rmse: 154895 + 6602.94
# [351]	cv_agg's rmse: 154846 + 6600.87
# [352]	cv_agg's rmse: 154796 + 6598.64
# [353]	cv_agg's rmse: 154748 + 6597
# [354]	cv_agg's rmse: 154699 + 6595.87
# [355]	cv_agg's rmse: 154649 + 6595.42
# [356]	cv_agg's rmse: 154600 + 6593.85
# [357]	cv_agg's rmse: 154551 + 6592.57
# [358]	cv_agg's rmse: 154503 + 6591.61
# [359]	cv_agg's rmse: 154455 + 6589.91
# [360]	cv_agg's rmse: 154406 + 6588.13
# [361]	cv_agg's rmse: 154358 + 6586.64
# [362]	cv_agg's rmse: 154309 + 6584.69
# [363]	cv_agg's rmse: 154261 + 6583.01
# [364]	cv_agg's rmse: 154213 + 6582.95
# [365]	cv_agg's rmse: 154166 + 6580.52
# [366]	cv_agg's rmse: 154117 + 6578.94
# [367]	cv_agg's rmse: 154069 + 6578.73
# [368]	cv_agg's rmse: 154022 + 6576.79
# [369]	cv_agg's rmse: 153974 + 6577.15
# [370]	cv_agg's rmse: 153928 + 6575.79
# [371]	cv_agg's rmse: 153879 + 6575.53
# [372]	cv_agg's rmse: 153832 + 6574.49
# [373]	cv_agg's rmse: 153785 + 6573.13
# [374]	cv_agg's rmse: 153738 + 6572.53
# [375]	cv_agg's rmse: 153691 + 6571.72
# [376]	cv_agg's rmse: 153644 + 6570.5
# [377]	cv_agg's rmse: 153597 + 6569.13
# [378]	cv_agg's rmse: 153550 + 6567.64
# [379]	cv_agg's rmse: 153504 + 6566.84
# [380]	cv_agg's rmse: 153457 + 6565.27
# [381]	cv_agg's rmse: 153413 + 6564.13
# [382]	cv_agg's rmse: 153367 + 6563.71
# [383]	cv_agg's rmse: 153320 + 6562.43
# [384]	cv_agg's rmse: 153274 + 6561.61
# [385]	cv_agg's rmse: 153228 + 6559.99
# [386]	cv_agg's rmse: 153182 + 6558.9
# [387]	cv_agg's rmse: 153137 + 6557.95
# [388]	cv_agg's rmse: 153091 + 6556.31
# [389]	cv_agg's rmse: 153045 + 6555.52
# [390]	cv_agg's rmse: 152999 + 6555.67
# [391]	cv_agg's rmse: 152954 + 6554.04
# [392]	cv_agg's rmse: 152908 + 6552.59
# [393]	cv_agg's rmse: 152864 + 6551.19
# [394]	cv_agg's rmse: 152818 + 6550.41
# [395]	cv_agg's rmse: 152772 + 6548.85
# [396]	cv_agg's rmse: 152727 + 6547.22
# [397]	cv_agg's rmse: 152682 + 6546.05
# [398]	cv_agg's rmse: 152636 + 6544.43
# [399]	cv_agg's rmse: 152591 + 6542.29
# [400]	cv_agg's rmse: 152545 + 6541.48
# [401]	cv_agg's rmse: 152501 + 6539.9
# [402]	cv_agg's rmse: 152455 + 6538.3
# [403]	cv_agg's rmse: 152411 + 6537.26
# [404]	cv_agg's rmse: 152365 + 6535.31
# [405]	cv_agg's rmse: 152321 + 6533.56
# [406]	cv_agg's rmse: 152276 + 6531.45
# [407]	cv_agg's rmse: 152232 + 6530.23
# [408]	cv_agg's rmse: 152187 + 6529.26
# [409]	cv_agg's rmse: 152143 + 6527.17
# [410]	cv_agg's rmse: 152097 + 6525.99
# [411]	cv_agg's rmse: 152053 + 6524.66
# [412]	cv_agg's rmse: 152008 + 6524.15
# [413]	cv_agg's rmse: 151964 + 6521.24
# [414]	cv_agg's rmse: 151920 + 6519.65
# [415]	cv_agg's rmse: 151876 + 6518.93
# [416]	cv_agg's rmse: 151831 + 6516.69
# [417]	cv_agg's rmse: 151788 + 6514.71
# [418]	cv_agg's rmse: 151744 + 6513.78
# [419]	cv_agg's rmse: 151700 + 6511.6
# [420]	cv_agg's rmse: 151655 + 6510.53
# [421]	cv_agg's rmse: 151613 + 6508.79
# [422]	cv_agg's rmse: 151568 + 6506.71
# [423]	cv_agg's rmse: 151524 + 6505.69
# [424]	cv_agg's rmse: 151480 + 6504.08
# [425]	cv_agg's rmse: 151437 + 6501.19
# [426]	cv_agg's rmse: 151393 + 6500.06
# [427]	cv_agg's rmse: 151349 + 6497.42
# [428]	cv_agg's rmse: 151304 + 6496.54
# [429]	cv_agg's rmse: 151261 + 6494.23
# [430]	cv_agg's rmse: 151217 + 6493.95
# [431]	cv_agg's rmse: 151174 + 6491.62
# [432]	cv_agg's rmse: 151130 + 6490.12
# [433]	cv_agg's rmse: 151087 + 6487.85
# [434]	cv_agg's rmse: 151044 + 6488.56
# [435]	cv_agg's rmse: 151000 + 6486.07
# [436]	cv_agg's rmse: 150957 + 6484.1
# [437]	cv_agg's rmse: 150914 + 6482.46
# [438]	cv_agg's rmse: 150871 + 6479.82
# [439]	cv_agg's rmse: 150828 + 6478.29
# [440]	cv_agg's rmse: 150785 + 6476.5
# [441]	cv_agg's rmse: 150742 + 6474.53
# [442]	cv_agg's rmse: 150699 + 6472.91
# [443]	cv_agg's rmse: 150656 + 6471.21
# [444]	cv_agg's rmse: 150615 + 6469.47
# [445]	cv_agg's rmse: 150572 + 6468.21
# [446]	cv_agg's rmse: 150530 + 6466.91
# [447]	cv_agg's rmse: 150488 + 6464.61
# [448]	cv_agg's rmse: 150447 + 6463.61
# [449]	cv_agg's rmse: 150405 + 6462.95
# [450]	cv_agg's rmse: 150363 + 6460.95
# [451]	cv_agg's rmse: 150321 + 6459.07
# [452]	cv_agg's rmse: 150280 + 6457.47
# [453]	cv_agg's rmse: 150238 + 6455.25
# [454]	cv_agg's rmse: 150197 + 6454.84
# [455]	cv_agg's rmse: 150155 + 6453.09
# [456]	cv_agg's rmse: 150114 + 6451.41
# [457]	cv_agg's rmse: 150073 + 6450.43
# [458]	cv_agg's rmse: 150032 + 6448.74
# [459]	cv_agg's rmse: 149991 + 6447.5
# [460]	cv_agg's rmse: 149949 + 6446.45
# [461]	cv_agg's rmse: 149908 + 6444.95
# [462]	cv_agg's rmse: 149867 + 6443.28
# [463]	cv_agg's rmse: 149826 + 6442.08
# [464]	cv_agg's rmse: 149785 + 6440.11
# [465]	cv_agg's rmse: 149745 + 6438.54
# [466]	cv_agg's rmse: 149704 + 6436.89
# [467]	cv_agg's rmse: 149663 + 6435.36
# [468]	cv_agg's rmse: 149621 + 6433.79
# [469]	cv_agg's rmse: 149581 + 6431.92
# [470]	cv_agg's rmse: 149541 + 6430.42
# [471]	cv_agg's rmse: 149500 + 6428.69
# [472]	cv_agg's rmse: 149459 + 6426.87
# [473]	cv_agg's rmse: 149419 + 6425.11
# [474]	cv_agg's rmse: 149378 + 6424.47
# [475]	cv_agg's rmse: 149337 + 6422.47
# [476]	cv_agg's rmse: 149297 + 6420.62
# [477]	cv_agg's rmse: 149258 + 6419.02
# [478]	cv_agg's rmse: 149218 + 6417.83
# [479]	cv_agg's rmse: 149177 + 6416.34
# [480]	cv_agg's rmse: 149137 + 6414.08
# [481]	cv_agg's rmse: 149097 + 6412.66
# [482]	cv_agg's rmse: 149057 + 6411.12
# [483]	cv_agg's rmse: 149017 + 6411.23
# [484]	cv_agg's rmse: 148977 + 6409.07
# [485]	cv_agg's rmse: 148938 + 6407.92
# [486]	cv_agg's rmse: 148898 + 6405.74
# [487]	cv_agg's rmse: 148859 + 6404.23
# [488]	cv_agg's rmse: 148819 + 6402.05
# [489]	cv_agg's rmse: 148779 + 6401.49
# [490]	cv_agg's rmse: 148739 + 6399.37
# [491]	cv_agg's rmse: 148699 + 6397.87
# [492]	cv_agg's rmse: 148659 + 6396.53
# [493]	cv_agg's rmse: 148619 + 6394.79
# [494]	cv_agg's rmse: 148579 + 6393.5
# [495]	cv_agg's rmse: 148539 + 6391.26
# [496]	cv_agg's rmse: 148500 + 6389.71
# [497]	cv_agg's rmse: 148460 + 6388.02
# [498]	cv_agg's rmse: 148421 + 6386.13
# [499]	cv_agg's rmse: 148379 + 6384.82
# [500]	cv_agg's rmse: 148341 + 6383.77
# [501]	cv_agg's rmse: 148300 + 6382.35
# [502]	cv_agg's rmse: 148260 + 6381.44
# [503]	cv_agg's rmse: 148220 + 6379.55
# [504]	cv_agg's rmse: 148182 + 6378.47
# [505]	cv_agg's rmse: 148141 + 6376.28
# [506]	cv_agg's rmse: 148102 + 6376.43
# [507]	cv_agg's rmse: 148062 + 6374.26
# [508]	cv_agg's rmse: 148023 + 6372.34
# [509]	cv_agg's rmse: 147984 + 6371.78
# [510]	cv_agg's rmse: 147945 + 6369.68
# [511]	cv_agg's rmse: 147906 + 6368.61
# [512]	cv_agg's rmse: 147867 + 6366.7
# [513]	cv_agg's rmse: 147829 + 6365.01
# [514]	cv_agg's rmse: 147790 + 6363.51
# [515]	cv_agg's rmse: 147752 + 6362.02
# [516]	cv_agg's rmse: 147712 + 6360.23
# [517]	cv_agg's rmse: 147674 + 6358.62
# [518]	cv_agg's rmse: 147636 + 6356.94
# [519]	cv_agg's rmse: 147598 + 6355.46
# [520]	cv_agg's rmse: 147559 + 6353.93
# [521]	cv_agg's rmse: 147522 + 6352.95
# [522]	cv_agg's rmse: 147482 + 6351.42
# [523]	cv_agg's rmse: 147444 + 6350.37
# [524]	cv_agg's rmse: 147406 + 6348.77
# [525]	cv_agg's rmse: 147368 + 6347.21
# [526]	cv_agg's rmse: 147329 + 6346.31
# [527]	cv_agg's rmse: 147291 + 6345.3
# [528]	cv_agg's rmse: 147253 + 6343.27
# [529]	cv_agg's rmse: 147215 + 6343.22
# [530]	cv_agg's rmse: 147177 + 6340.5
# [531]	cv_agg's rmse: 147139 + 6339.48
# [532]	cv_agg's rmse: 147102 + 6338.15
# [533]	cv_agg's rmse: 147063 + 6336.9
# [534]	cv_agg's rmse: 147025 + 6334.53
# [535]	cv_agg's rmse: 146987 + 6333.1
# [536]	cv_agg's rmse: 146950 + 6332.04
# [537]	cv_agg's rmse: 146911 + 6330.68
# [538]	cv_agg's rmse: 146875 + 6329.55
# [539]	cv_agg's rmse: 146837 + 6328.63
# [540]	cv_agg's rmse: 146799 + 6326.53
# [541]	cv_agg's rmse: 146763 + 6325.49
# [542]	cv_agg's rmse: 146725 + 6324.06
# [543]	cv_agg's rmse: 146686 + 6322.62
# [544]	cv_agg's rmse: 146649 + 6321.57
# [545]	cv_agg's rmse: 146610 + 6320.22
# [546]	cv_agg's rmse: 146574 + 6318.47
# [547]	cv_agg's rmse: 146536 + 6317.01
# [548]	cv_agg's rmse: 146499 + 6315.12
# [549]	cv_agg's rmse: 146462 + 6313.92
# [550]	cv_agg's rmse: 146425 + 6312.93
# [551]	cv_agg's rmse: 146388 + 6311
# [552]	cv_agg's rmse: 146351 + 6309.73
# [553]	cv_agg's rmse: 146315 + 6307.3
# [554]	cv_agg's rmse: 146278 + 6306.5
# [555]	cv_agg's rmse: 146242 + 6303.93
# [556]	cv_agg's rmse: 146204 + 6302.18
# [557]	cv_agg's rmse: 146167 + 6300.42
# [558]	cv_agg's rmse: 146130 + 6298.32
# [559]	cv_agg's rmse: 146094 + 6296.85
# [560]	cv_agg's rmse: 146057 + 6295.08
# [561]	cv_agg's rmse: 146021 + 6293.06
# [562]	cv_agg's rmse: 145984 + 6290.96
# [563]	cv_agg's rmse: 145947 + 6289.28
# [564]	cv_agg's rmse: 145911 + 6287.28
# [565]	cv_agg's rmse: 145874 + 6285.38
# [566]	cv_agg's rmse: 145838 + 6282.77
# [567]	cv_agg's rmse: 145802 + 6281.94
# [568]	cv_agg's rmse: 145766 + 6279.12
# [569]	cv_agg's rmse: 145730 + 6277.33
# [570]	cv_agg's rmse: 145694 + 6275.83
# [571]	cv_agg's rmse: 145657 + 6273.81
# [572]	cv_agg's rmse: 145622 + 6272.65
# [573]	cv_agg's rmse: 145585 + 6270.77
# [574]	cv_agg's rmse: 145548 + 6269.15
# [575]	cv_agg's rmse: 145512 + 6267.12
# [576]	cv_agg's rmse: 145477 + 6265.26
# [577]	cv_agg's rmse: 145441 + 6263.57
# [578]	cv_agg's rmse: 145405 + 6261.78
# [579]	cv_agg's rmse: 145368 + 6259.43
# [580]	cv_agg's rmse: 145333 + 6257.86
# [581]	cv_agg's rmse: 145298 + 6256.38
# [582]	cv_agg's rmse: 145262 + 6254.13
# [583]	cv_agg's rmse: 145226 + 6252.78
# [584]	cv_agg's rmse: 145190 + 6250.44
# [585]	cv_agg's rmse: 145155 + 6248.58
# [586]	cv_agg's rmse: 145119 + 6247
# [587]	cv_agg's rmse: 145084 + 6245.21
# [588]	cv_agg's rmse: 145049 + 6242.82
# [589]	cv_agg's rmse: 145014 + 6240.81
# [590]	cv_agg's rmse: 144978 + 6241.7
# [591]	cv_agg's rmse: 144943 + 6239.46
# [592]	cv_agg's rmse: 144907 + 6239.08
# [593]	cv_agg's rmse: 144871 + 6236.69
# [594]	cv_agg's rmse: 144836 + 6234.51
# [595]	cv_agg's rmse: 144801 + 6234.21
# [596]	cv_agg's rmse: 144766 + 6231.77
# [597]	cv_agg's rmse: 144730 + 6230.22
# [598]	cv_agg's rmse: 144695 + 6228.92
# [599]	cv_agg's rmse: 144661 + 6226.82
# [600]	cv_agg's rmse: 144625 + 6224.7
# [601]	cv_agg's rmse: 144590 + 6223.22
# [602]	cv_agg's rmse: 144556 + 6220.78
# [603]	cv_agg's rmse: 144521 + 6220.35
# [604]	cv_agg's rmse: 144487 + 6218.17
# [605]	cv_agg's rmse: 144451 + 6215.93
# [606]	cv_agg's rmse: 144417 + 6214.99
# [607]	cv_agg's rmse: 144383 + 6213.32
# [608]	cv_agg's rmse: 144348 + 6210.46
# [609]	cv_agg's rmse: 144313 + 6208.8
# [610]	cv_agg's rmse: 144279 + 6207.97
# [611]	cv_agg's rmse: 144244 + 6206.09
# [612]	cv_agg's rmse: 144209 + 6203.89
# [613]	cv_agg's rmse: 144175 + 6202.18
# [614]	cv_agg's rmse: 144141 + 6200.92
# [615]	cv_agg's rmse: 144107 + 6198.83
# [616]	cv_agg's rmse: 144073 + 6197.8
# [617]	cv_agg's rmse: 144039 + 6195.81
# [618]	cv_agg's rmse: 144006 + 6193.97
# [619]	cv_agg's rmse: 143971 + 6193.34
# [620]	cv_agg's rmse: 143938 + 6191.2
# [621]	cv_agg's rmse: 143903 + 6188.97
# [622]	cv_agg's rmse: 143869 + 6187.45
# [623]	cv_agg's rmse: 143836 + 6185.99
# [624]	cv_agg's rmse: 143802 + 6183.79
# [625]	cv_agg's rmse: 143768 + 6181.24
# [626]	cv_agg's rmse: 143736 + 6179.35
# [627]	cv_agg's rmse: 143702 + 6177.5
# [628]	cv_agg's rmse: 143669 + 6176.01
# [629]	cv_agg's rmse: 143637 + 6173.92
# [630]	cv_agg's rmse: 143603 + 6171.52
# [631]	cv_agg's rmse: 143571 + 6170.06
# [632]	cv_agg's rmse: 143538 + 6169.61
# [633]	cv_agg's rmse: 143505 + 6167.28
# [634]	cv_agg's rmse: 143472 + 6165.21
# [635]	cv_agg's rmse: 143439 + 6163.9
# [636]	cv_agg's rmse: 143406 + 6162.51
# [637]	cv_agg's rmse: 143372 + 6159.65
# [638]	cv_agg's rmse: 143339 + 6157.29
# [639]	cv_agg's rmse: 143306 + 6155.51
# [640]	cv_agg's rmse: 143273 + 6153.99
# [641]	cv_agg's rmse: 143240 + 6152.03
# [642]	cv_agg's rmse: 143208 + 6148.77
# [643]	cv_agg's rmse: 143175 + 6146.88
# [644]	cv_agg's rmse: 143142 + 6145.62
# [645]	cv_agg's rmse: 143110 + 6143.52
# [646]	cv_agg's rmse: 143078 + 6141.25
# [647]	cv_agg's rmse: 143045 + 6138.55
# [648]	cv_agg's rmse: 143012 + 6136.77
# [649]	cv_agg's rmse: 142979 + 6134.25
# [650]	cv_agg's rmse: 142947 + 6132.16
# [651]	cv_agg's rmse: 142915 + 6129.83
# [652]	cv_agg's rmse: 142881 + 6127.83
# [653]	cv_agg's rmse: 142848 + 6125.26
# [654]	cv_agg's rmse: 142815 + 6123.07
# [655]	cv_agg's rmse: 142784 + 6120.48
# [656]	cv_agg's rmse: 142752 + 6117.84
# [657]	cv_agg's rmse: 142718 + 6116.33
# [658]	cv_agg's rmse: 142686 + 6113.82
# [659]	cv_agg's rmse: 142655 + 6110.71
# [660]	cv_agg's rmse: 142624 + 6108.37
# [661]	cv_agg's rmse: 142592 + 6105.84
# [662]	cv_agg's rmse: 142559 + 6102.12
# [663]	cv_agg's rmse: 142527 + 6098.84
# [664]	cv_agg's rmse: 142495 + 6095.61
# [665]	cv_agg's rmse: 142464 + 6092.44
# [666]	cv_agg's rmse: 142432 + 6089.24
# [667]	cv_agg's rmse: 142400 + 6087.67
# [668]	cv_agg's rmse: 142369 + 6085.2
# [669]	cv_agg's rmse: 142337 + 6083.03
# [670]	cv_agg's rmse: 142306 + 6081.97
# [671]	cv_agg's rmse: 142275 + 6080.32
# [672]	cv_agg's rmse: 142245 + 6077.84
# [673]	cv_agg's rmse: 142213 + 6074.12
# [674]	cv_agg's rmse: 142182 + 6070.93
# [675]	cv_agg's rmse: 142150 + 6069.67
# [676]	cv_agg's rmse: 142118 + 6066.77
# [677]	cv_agg's rmse: 142087 + 6065.32
# [678]	cv_agg's rmse: 142055 + 6063.44
# [679]	cv_agg's rmse: 142024 + 6060.68
# [680]	cv_agg's rmse: 141993 + 6058.75
# [681]	cv_agg's rmse: 141963 + 6057.01
# [682]	cv_agg's rmse: 141932 + 6054.48
# [683]	cv_agg's rmse: 141901 + 6051.52
# [684]	cv_agg's rmse: 141869 + 6049.07
# [685]	cv_agg's rmse: 141838 + 6046.99
# [686]	cv_agg's rmse: 141807 + 6045
# [687]	cv_agg's rmse: 141777 + 6041.89
# [688]	cv_agg's rmse: 141747 + 6040.53
# [689]	cv_agg's rmse: 141716 + 6037.97
# [690]	cv_agg's rmse: 141686 + 6036.17
# [691]	cv_agg's rmse: 141654 + 6034.89
# [692]	cv_agg's rmse: 141624 + 6033.26
# [693]	cv_agg's rmse: 141594 + 6030.25
# [694]	cv_agg's rmse: 141564 + 6028.97
# [695]	cv_agg's rmse: 141533 + 6028.34
# [696]	cv_agg's rmse: 141503 + 6026.17
# [697]	cv_agg's rmse: 141473 + 6023.63
# [698]	cv_agg's rmse: 141442 + 6022.53
# [699]	cv_agg's rmse: 141411 + 6020.61
# [700]	cv_agg's rmse: 141382 + 6018.72
# [701]	cv_agg's rmse: 141352 + 6015.73
# [702]	cv_agg's rmse: 141320 + 6014
# [703]	cv_agg's rmse: 141291 + 6011.52
# [704]	cv_agg's rmse: 141261 + 6008.99
# [705]	cv_agg's rmse: 141232 + 6006.99
# [706]	cv_agg's rmse: 141202 + 6005.33
# [707]	cv_agg's rmse: 141172 + 6003.73
# [708]	cv_agg's rmse: 141141 + 6002.14
# [709]	cv_agg's rmse: 141111 + 6000.83
# [710]	cv_agg's rmse: 141082 + 5998.58
# [711]	cv_agg's rmse: 141053 + 5995.66
# [712]	cv_agg's rmse: 141022 + 5995.36
# [713]	cv_agg's rmse: 140992 + 5993.3
# [714]	cv_agg's rmse: 140964 + 5991.33
# [715]	cv_agg's rmse: 140934 + 5989.95
# [716]	cv_agg's rmse: 140904 + 5989.91
# [717]	cv_agg's rmse: 140875 + 5987.15
# [718]	cv_agg's rmse: 140846 + 5984.52
# [719]	cv_agg's rmse: 140816 + 5983.11
# [720]	cv_agg's rmse: 140788 + 5980.98
# [721]	cv_agg's rmse: 140758 + 5979.65
# [722]	cv_agg's rmse: 140729 + 5977.98
# [723]	cv_agg's rmse: 140700 + 5976.56
# [724]	cv_agg's rmse: 140670 + 5974.76
# [725]	cv_agg's rmse: 140641 + 5972.86
# [726]	cv_agg's rmse: 140613 + 5970.33
# [727]	cv_agg's rmse: 140584 + 5968.24
# [728]	cv_agg's rmse: 140555 + 5968.49
# [729]	cv_agg's rmse: 140526 + 5965.38
# [730]	cv_agg's rmse: 140498 + 5963.9
# [731]	cv_agg's rmse: 140470 + 5961.94
# [732]	cv_agg's rmse: 140441 + 5960.79
# [733]	cv_agg's rmse: 140413 + 5957.65
# [734]	cv_agg's rmse: 140385 + 5956.25
# [735]	cv_agg's rmse: 140355 + 5955.42
# [736]	cv_agg's rmse: 140326 + 5953.39
# [737]	cv_agg's rmse: 140299 + 5951.73
# [738]	cv_agg's rmse: 140270 + 5949.97
# [739]	cv_agg's rmse: 140243 + 5948.04
# [740]	cv_agg's rmse: 140215 + 5946.08
# [741]	cv_agg's rmse: 140188 + 5943.38
# [742]	cv_agg's rmse: 140158 + 5942.22
# [743]	cv_agg's rmse: 140129 + 5939.58
# [744]	cv_agg's rmse: 140102 + 5938.21
# [745]	cv_agg's rmse: 140073 + 5935.33
# [746]	cv_agg's rmse: 140045 + 5934.68
# [747]	cv_agg's rmse: 140017 + 5932.05
# [748]	cv_agg's rmse: 139989 + 5930.53
# [749]	cv_agg's rmse: 139961 + 5929.18
# [750]	cv_agg's rmse: 139934 + 5928.16
# [751]	cv_agg's rmse: 139905 + 5926.5
# [752]	cv_agg's rmse: 139877 + 5926.04
# [753]	cv_agg's rmse: 139850 + 5924.58
# [754]	cv_agg's rmse: 139822 + 5922.95
# [755]	cv_agg's rmse: 139794 + 5920.64
# [756]	cv_agg's rmse: 139768 + 5919.61
# [757]	cv_agg's rmse: 139740 + 5919.04
# [758]	cv_agg's rmse: 139713 + 5916.83
# [759]	cv_agg's rmse: 139687 + 5915.98
# [760]	cv_agg's rmse: 139659 + 5914.99
# [761]	cv_agg's rmse: 139630 + 5914.29
# [762]	cv_agg's rmse: 139602 + 5913.3
# [763]	cv_agg's rmse: 139575 + 5912.31
# [764]	cv_agg's rmse: 139549 + 5910.65
# [765]	cv_agg's rmse: 139520 + 5909.89
# [766]	cv_agg's rmse: 139493 + 5909.93
# [767]	cv_agg's rmse: 139466 + 5908.67
# [768]	cv_agg's rmse: 139439 + 5908
# [769]	cv_agg's rmse: 139412 + 5906.55
# [770]	cv_agg's rmse: 139385 + 5905.23
# [771]	cv_agg's rmse: 139357 + 5905.06
# [772]	cv_agg's rmse: 139331 + 5903.3
# [773]	cv_agg's rmse: 139304 + 5902.55
# [774]	cv_agg's rmse: 139278 + 5901.16
# [775]	cv_agg's rmse: 139251 + 5899.43
# [776]	cv_agg's rmse: 139224 + 5897.71
# [777]	cv_agg's rmse: 139196 + 5897.88
# [778]	cv_agg's rmse: 139169 + 5896.24
# [779]	cv_agg's rmse: 139142 + 5895.74
# [780]	cv_agg's rmse: 139115 + 5894.88
# [781]	cv_agg's rmse: 139089 + 5893.33
# [782]	cv_agg's rmse: 139063 + 5891.26
# [783]	cv_agg's rmse: 139036 + 5889.75
# [784]	cv_agg's rmse: 139009 + 5887.63
# [785]	cv_agg's rmse: 138982 + 5886.49
# [786]	cv_agg's rmse: 138956 + 5884.53
# [787]	cv_agg's rmse: 138929 + 5884.06
# [788]	cv_agg's rmse: 138902 + 5882.56
# [789]	cv_agg's rmse: 138876 + 5880.28
# [790]	cv_agg's rmse: 138850 + 5879.34
# [791]	cv_agg's rmse: 138824 + 5877.04
# [792]	cv_agg's rmse: 138798 + 5875.09
# [793]	cv_agg's rmse: 138771 + 5874.72
# [794]	cv_agg's rmse: 138745 + 5873.63
# [795]	cv_agg's rmse: 138718 + 5872.21
# [796]	cv_agg's rmse: 138693 + 5871.12
# [797]	cv_agg's rmse: 138667 + 5869.73
# [798]	cv_agg's rmse: 138640 + 5867.56
# [799]	cv_agg's rmse: 138615 + 5867.11
# [800]	cv_agg's rmse: 138589 + 5865.56
# [801]	cv_agg's rmse: 138564 + 5863.45
# [802]	cv_agg's rmse: 138540 + 5862.88
# [803]	cv_agg's rmse: 138514 + 5861.39
# [804]	cv_agg's rmse: 138487 + 5859.67
# [805]	cv_agg's rmse: 138462 + 5858.9
# [806]	cv_agg's rmse: 138438 + 5858.27
# [807]	cv_agg's rmse: 138413 + 5856.28
# [808]	cv_agg's rmse: 138388 + 5855.85
# [809]	cv_agg's rmse: 138362 + 5854.2
# [810]	cv_agg's rmse: 138337 + 5852.07
# [811]	cv_agg's rmse: 138313 + 5850.31
# [812]	cv_agg's rmse: 138287 + 5848.97
# [813]	cv_agg's rmse: 138261 + 5847.53
# [814]	cv_agg's rmse: 138236 + 5845.59
# [815]	cv_agg's rmse: 138212 + 5844.86
# [816]	cv_agg's rmse: 138186 + 5843.79
# [817]	cv_agg's rmse: 138162 + 5842.59
# [818]	cv_agg's rmse: 138136 + 5842.75
# [819]	cv_agg's rmse: 138112 + 5840.88
# [820]	cv_agg's rmse: 138087 + 5839.17
# [821]	cv_agg's rmse: 138063 + 5837.74
# [822]	cv_agg's rmse: 138037 + 5836.45
# [823]	cv_agg's rmse: 138012 + 5834.97
# [824]	cv_agg's rmse: 137987 + 5833.34
# [825]	cv_agg's rmse: 137963 + 5831.97
# [826]	cv_agg's rmse: 137938 + 5829.52
# [827]	cv_agg's rmse: 137913 + 5828.18
# [828]	cv_agg's rmse: 137889 + 5826.42
# [829]	cv_agg's rmse: 137865 + 5825.29
# [830]	cv_agg's rmse: 137840 + 5823.89
# [831]	cv_agg's rmse: 137815 + 5823.08
# [832]	cv_agg's rmse: 137791 + 5821.26
# [833]	cv_agg's rmse: 137765 + 5819.08
# [834]	cv_agg's rmse: 137741 + 5817.43
# [835]	cv_agg's rmse: 137716 + 5815.55
# [836]	cv_agg's rmse: 137693 + 5814.4
# [837]	cv_agg's rmse: 137668 + 5813.03
# [838]	cv_agg's rmse: 137644 + 5811.84
# [839]	cv_agg's rmse: 137619 + 5810.37
# [840]	cv_agg's rmse: 137595 + 5809.05
# [841]	cv_agg's rmse: 137571 + 5807.31
# [842]	cv_agg's rmse: 137547 + 5805.25
# [843]	cv_agg's rmse: 137523 + 5803.8
# [844]	cv_agg's rmse: 137498 + 5802.86
# [845]	cv_agg's rmse: 137474 + 5800.89
# [846]	cv_agg's rmse: 137450 + 5799.29
# [847]	cv_agg's rmse: 137426 + 5798.2
# [848]	cv_agg's rmse: 137401 + 5796
# [849]	cv_agg's rmse: 137377 + 5794.09
# [850]	cv_agg's rmse: 137353 + 5792.51
# [851]	cv_agg's rmse: 137329 + 5790.16
# [852]	cv_agg's rmse: 137304 + 5788.57
# [853]	cv_agg's rmse: 137280 + 5787.06
# [854]	cv_agg's rmse: 137255 + 5785.2
# [855]	cv_agg's rmse: 137231 + 5783.2
# [856]	cv_agg's rmse: 137208 + 5782.14
# [857]	cv_agg's rmse: 137184 + 5780.29
# [858]	cv_agg's rmse: 137160 + 5779.56
# [859]	cv_agg's rmse: 137135 + 5777.74
# [860]	cv_agg's rmse: 137112 + 5776.5
# [861]	cv_agg's rmse: 137088 + 5775.03
# [862]	cv_agg's rmse: 137064 + 5772.79
# [863]	cv_agg's rmse: 137040 + 5771.13
# [864]	cv_agg's rmse: 137016 + 5769.47
# [865]	cv_agg's rmse: 136992 + 5767.73
# [866]	cv_agg's rmse: 136968 + 5766.22
# [867]	cv_agg's rmse: 136944 + 5765.02
# [868]	cv_agg's rmse: 136920 + 5762.94
# [869]	cv_agg's rmse: 136896 + 5761.32
# [870]	cv_agg's rmse: 136872 + 5760.14
# [871]	cv_agg's rmse: 136846 + 5759.44
# [872]	cv_agg's rmse: 136822 + 5758.06
# [873]	cv_agg's rmse: 136798 + 5756.97
# [874]	cv_agg's rmse: 136775 + 5754.94
# [875]	cv_agg's rmse: 136751 + 5753.26
# [876]	cv_agg's rmse: 136726 + 5751.46
# [877]	cv_agg's rmse: 136703 + 5749.99
# [878]	cv_agg's rmse: 136679 + 5747.79
# [879]	cv_agg's rmse: 136655 + 5745.59
# [880]	cv_agg's rmse: 136632 + 5744.23
# [881]	cv_agg's rmse: 136608 + 5742.51
# [882]	cv_agg's rmse: 136584 + 5739.93
# [883]	cv_agg's rmse: 136560 + 5737.8
# [884]	cv_agg's rmse: 136537 + 5737.17
# [885]	cv_agg's rmse: 136513 + 5735.86
# [886]	cv_agg's rmse: 136489 + 5733.84
# [887]	cv_agg's rmse: 136466 + 5731.97
# [888]	cv_agg's rmse: 136443 + 5729.82
# [889]	cv_agg's rmse: 136419 + 5728.56
# [890]	cv_agg's rmse: 136395 + 5728.03
# [891]	cv_agg's rmse: 136373 + 5726.19
# [892]	cv_agg's rmse: 136350 + 5724.77
# [893]	cv_agg's rmse: 136326 + 5722.63
# [894]	cv_agg's rmse: 136302 + 5721.45
# [895]	cv_agg's rmse: 136280 + 5720.38
# [896]	cv_agg's rmse: 136256 + 5718.97
# [897]	cv_agg's rmse: 136234 + 5717.36
# [898]	cv_agg's rmse: 136210 + 5715.85
# [899]	cv_agg's rmse: 136187 + 5714.92
# [900]	cv_agg's rmse: 136164 + 5712.36
# [901]	cv_agg's rmse: 136140 + 5711.03
# [902]	cv_agg's rmse: 136116 + 5709.91
# [903]	cv_agg's rmse: 136093 + 5708.63
# [904]	cv_agg's rmse: 136069 + 5707.56
# [905]	cv_agg's rmse: 136046 + 5706.14
# [906]	cv_agg's rmse: 136024 + 5705.08
# [907]	cv_agg's rmse: 136000 + 5703.44
# [908]	cv_agg's rmse: 135979 + 5702.31
# [909]	cv_agg's rmse: 135955 + 5702.45
# [910]	cv_agg's rmse: 135932 + 5701.08
# [911]	cv_agg's rmse: 135909 + 5699.62
# [912]	cv_agg's rmse: 135886 + 5698.22
# [913]	cv_agg's rmse: 135863 + 5697.05
# [914]	cv_agg's rmse: 135841 + 5696.32
# [915]	cv_agg's rmse: 135819 + 5695.24
# [916]	cv_agg's rmse: 135796 + 5693.97
# [917]	cv_agg's rmse: 135774 + 5692.86
# [918]	cv_agg's rmse: 135751 + 5691.81
# [919]	cv_agg's rmse: 135728 + 5690.25
# [920]	cv_agg's rmse: 135706 + 5688.74
# [921]	cv_agg's rmse: 135684 + 5687.67
# [922]	cv_agg's rmse: 135661 + 5686.17
# [923]	cv_agg's rmse: 135638 + 5685.64
# [924]	cv_agg's rmse: 135616 + 5685.25
# [925]	cv_agg's rmse: 135594 + 5683.66
# [926]	cv_agg's rmse: 135572 + 5682.48
# [927]	cv_agg's rmse: 135550 + 5681.28
# [928]	cv_agg's rmse: 135527 + 5679.71
# [929]	cv_agg's rmse: 135505 + 5678.43
# [930]	cv_agg's rmse: 135484 + 5677.42
# [931]	cv_agg's rmse: 135461 + 5675.8
# [932]	cv_agg's rmse: 135439 + 5675.77
# [933]	cv_agg's rmse: 135417 + 5674.9
# [934]	cv_agg's rmse: 135395 + 5673.82
# [935]	cv_agg's rmse: 135373 + 5673.3
# [936]	cv_agg's rmse: 135351 + 5671.9
# [937]	cv_agg's rmse: 135328 + 5670.77
# [938]	cv_agg's rmse: 135307 + 5669.66
# [939]	cv_agg's rmse: 135286 + 5668.7
# [940]	cv_agg's rmse: 135264 + 5667.92
# [941]	cv_agg's rmse: 135242 + 5666.61
# [942]	cv_agg's rmse: 135220 + 5665.12
# [943]	cv_agg's rmse: 135198 + 5663.95
# [944]	cv_agg's rmse: 135176 + 5662.38
# [945]	cv_agg's rmse: 135154 + 5661.99
# [946]	cv_agg's rmse: 135133 + 5660.64
# [947]	cv_agg's rmse: 135112 + 5659.26
# [948]	cv_agg's rmse: 135090 + 5658.84
# [949]	cv_agg's rmse: 135069 + 5657.7
# [950]	cv_agg's rmse: 135047 + 5655.57
# [951]	cv_agg's rmse: 135027 + 5654.69
# [952]	cv_agg's rmse: 135006 + 5654.07
# [953]	cv_agg's rmse: 134984 + 5652.6
# [954]	cv_agg's rmse: 134962 + 5652.72
# [955]	cv_agg's rmse: 134940 + 5651.67
# [956]	cv_agg's rmse: 134919 + 5651.63
# [957]	cv_agg's rmse: 134899 + 5650.38
# [958]	cv_agg's rmse: 134877 + 5649.72
# [959]	cv_agg's rmse: 134856 + 5648.75
# [960]	cv_agg's rmse: 134835 + 5648.15
# [961]	cv_agg's rmse: 134815 + 5647.3
# [962]	cv_agg's rmse: 134795 + 5646.6
# [963]	cv_agg's rmse: 134773 + 5645.25
# [964]	cv_agg's rmse: 134753 + 5644.96
# [965]	cv_agg's rmse: 134732 + 5644.2
# [966]	cv_agg's rmse: 134712 + 5643.11
# [967]	cv_agg's rmse: 134691 + 5643.08
# [968]	cv_agg's rmse: 134670 + 5642.59
# [969]	cv_agg's rmse: 134650 + 5641.91
# [970]	cv_agg's rmse: 134628 + 5640.55
# [971]	cv_agg's rmse: 134608 + 5640.1
# [972]	cv_agg's rmse: 134588 + 5639.32
# [973]	cv_agg's rmse: 134567 + 5637.69
# [974]	cv_agg's rmse: 134546 + 5636.36
# [975]	cv_agg's rmse: 134525 + 5635.76
# [976]	cv_agg's rmse: 134506 + 5635.51
# [977]	cv_agg's rmse: 134484 + 5634.7
# [978]	cv_agg's rmse: 134463 + 5634.35
# [979]	cv_agg's rmse: 134444 + 5633.2
# [980]	cv_agg's rmse: 134424 + 5632.41
# [981]	cv_agg's rmse: 134404 + 5631.39
# [982]	cv_agg's rmse: 134384 + 5630.75
# [983]	cv_agg's rmse: 134362 + 5629.7
# [984]	cv_agg's rmse: 134343 + 5628.48
# [985]	cv_agg's rmse: 134324 + 5628.65
# [986]	cv_agg's rmse: 134304 + 5627.29
# [987]	cv_agg's rmse: 134284 + 5627.56
# [988]	cv_agg's rmse: 134264 + 5626.84
# [989]	cv_agg's rmse: 134243 + 5625.71
# [990]	cv_agg's rmse: 134223 + 5625.52
# [991]	cv_agg's rmse: 134204 + 5624.24
# [992]	cv_agg's rmse: 134184 + 5623.44
# [993]	cv_agg's rmse: 134165 + 5623.74
# [994]	cv_agg's rmse: 134145 + 5621.95
# [995]	cv_agg's rmse: 134124 + 5620.13
# [996]	cv_agg's rmse: 134104 + 5619.22
# [997]	cv_agg's rmse: 134084 + 5618.68
# [998]	cv_agg's rmse: 134063 + 5616.94
# [999]	cv_agg's rmse: 134042 + 5616.99
# [1000]	cv_agg's rmse: 134024 + 5615.53

# %%
# params
print('Current parameters:\n', params)
print('\nBest num_boost_round:', len(cv_results['rmse-mean']))
print('Best CV score:', cv_results['rmse-mean'][-1])
# Out:
# Current parameters:
#  {'boosting_type': 'gbdt', 'objective': 'regression', 'metric': {'rmse'}, 'learning_rate': 0.001}
#
# Best num_boost_round: 1000
# Best CV score: 134023.82354100602

# %%
num_boost_rounds_lgb=len(cv_results['rmse-mean'])
model_lgb = lgb.train(params, dftrainLGB, num_boost_round=num_boost_rounds_lgb)

# %%
y_pred_lgb = model_lgb.predict(x_test)
y_pred_lgb[y_pred_lgb < 0] = 0

# %%
lgb_rmsle = rmsle(list(y_test), list(y_pred_lgb))

# %%
print('lightgbm RMSLE Score [learning rate, num of iteration] is {}'.format(lgb_rmsle))
# Out:
# lightgbm RMSLE Score [learning rate, num of iteration] is 3.695083389567998

# %% [markdown]
# ### using larger num_of_leaves for better accuracy

# %%
params = {
    'boosting_type': 'gbdt',
    'objective': 'regression',
    'metric': {'rmse'},
    'num_leave': 100
}

# %%
# training with more rounds
cv_results = lgb.cv(
    params,
    dftrainLGB,
    num_boost_round=500,
    nfold=10,
    early_stopping_rounds=100,
    stratified=False,
    verbose_eval=True
)
# Out:
# [1]	cv_agg's rmse: 169217 + 6853.87
# [2]	cv_agg's rmse: 162469 + 6922.88
# [3]	cv_agg's rmse: 156712 + 6828.7
# [4]	cv_agg's rmse: 151651 + 6627.8
# [5]	cv_agg's rmse: 147296 + 6559.29
# [6]	cv_agg's rmse: 143636 + 6405.42
# [7]	cv_agg's rmse: 140350 + 6249.69
# [8]	cv_agg's rmse: 137676 + 6148.8
# [9]	cv_agg's rmse: 135387 + 6055.95
# [10]	cv_agg's rmse: 133132 + 5877.36
# [11]	cv_agg's rmse: 131383 + 5906.72
# [12]	cv_agg's rmse: 129652 + 5709.31
# [13]	cv_agg's rmse: 128072 + 5646.13
# [14]	cv_agg's rmse: 126503 + 5558.58
# [15]	cv_agg's rmse: 125195 + 5334.46
# [16]	cv_agg's rmse: 124021 + 5156.91
# [17]	cv_agg's rmse: 122870 + 4972.13
# [18]	cv_agg's rmse: 121873 + 4914.21
# [19]	cv_agg's rmse: 120958 + 4751.24
# [20]	cv_agg's rmse: 120216 + 4555.82
# [21]	cv_agg's rmse: 119492 + 4539.3
# [22]	cv_agg's rmse: 118735 + 4468.24
# [23]	cv_agg's rmse: 118028 + 4465
# [24]	cv_agg's rmse: 117405 + 4344.15
# [25]	cv_agg's rmse: 116903 + 4336.18
# [26]	cv_agg's rmse: 116431 + 4350.64
# [27]	cv_agg's rmse: 115974 + 4330.3
# [28]	cv_agg's rmse: 115584 + 4197.87
# [29]	cv_agg's rmse: 115133 + 4115.69
# [30]	cv_agg's rmse: 114761 + 4140.21
# [31]	cv_agg's rmse: 114382 + 4217.56
# [32]	cv_agg's rmse: 113953 + 4197.56
# [33]	cv_agg's rmse: 113600 + 4138.01
# [34]	cv_agg's rmse: 113252 + 4048.89
# [35]	cv_agg's rmse: 112938 + 4065.37
# [36]	cv_agg's rmse: 112628 + 4049.2
# [37]	cv_agg's rmse: 112347 + 3998.65
# [38]	cv_agg's rmse: 111947 + 4125.77
# [39]	cv_agg's rmse: 111861 + 4084.03
# [40]	cv_agg's rmse: 111693 + 4020.06
# [41]	cv_agg's rmse: 111589 + 4047.46
# [42]	cv_agg's rmse: 111505 + 4086.31
# [43]	cv_agg's rmse: 111372 + 4087.62
# [44]	cv_agg's rmse: 111265 + 4082.88
# [45]	cv_agg's rmse: 111251 + 4089.01
# [46]	cv_agg's rmse: 111223 + 4070.93
# [47]	cv_agg's rmse: 111197 + 4059.36
# [48]	cv_agg's rmse: 111157 + 4081.35
# [49]	cv_agg's rmse: 111130 + 4085.52
# [50]	cv_agg's rmse: 111109 + 4060.98
# [51]	cv_agg's rmse: 111049 + 4063.93
# [52]	cv_agg's rmse: 110990 + 4072.42
# [53]	cv_agg's rmse: 110932 + 4051.73
# [54]	cv_agg's rmse: 110863 + 4086.72
# [55]	cv_agg's rmse: 110806 + 4048.18
# [56]	cv_agg's rmse: 110743 + 4016.23
# [57]	cv_agg's rmse: 110715 + 4005.13
# [58]	cv_agg's rmse: 110638 + 4012.31
# [59]	cv_agg's rmse: 110605 + 3997.58
# [60]	cv_agg's rmse: 110505 + 3992.59
# [61]	cv_agg's rmse: 110436 + 3977.5
# [62]	cv_agg's rmse: 110386 + 3998.47
# [63]	cv_agg's rmse: 110260 + 4025.58
# [64]	cv_agg's rmse: 110159 + 3978.99
# [65]	cv_agg's rmse: 110012 + 3863.44
# [66]	cv_agg's rmse: 109905 + 3862.13
# [67]	cv_agg's rmse: 109889 + 3834.04
# [68]	cv_agg's rmse: 109821 + 3833.99
# [69]	cv_agg's rmse: 109790 + 3829.73
# [70]	cv_agg's rmse: 109663 + 3827.57
# [71]	cv_agg's rmse: 109592 + 3843.14
# [72]	cv_agg's rmse: 109553 + 3831.3
# [73]	cv_agg's rmse: 109527 + 3806.63
# [74]	cv_agg's rmse: 109511 + 3799.92
# [75]	cv_agg's rmse: 109484 + 3792.73
# [76]	cv_agg's rmse: 109450 + 3754.06
# [77]	cv_agg's rmse: 109426 + 3737.41
# [78]	cv_agg's rmse: 109356 + 3752.93
# [79]	cv_agg's rmse: 109328 + 3736.26
# [80]	cv_agg's rmse: 109282 + 3766.77
# [81]	cv_agg's rmse: 109245 + 3779.44
# [82]	cv_agg's rmse: 109092 + 3779.32
# [83]	cv_agg's rmse: 109055 + 3755.38
# [84]	cv_agg's rmse: 108995 + 3754.9
# [85]	cv_agg's rmse: 108959 + 3760.06
# [86]	cv_agg's rmse: 108877 + 3784.26
# [87]	cv_agg's rmse: 108845 + 3724.37
# [88]	cv_agg's rmse: 108806 + 3718.61
# [89]	cv_agg's rmse: 108764 + 3762.87
# [90]	cv_agg's rmse: 108693 + 3764.35
# [91]	cv_agg's rmse: 108636 + 3757.43
# [92]	cv_agg's rmse: 108597 + 3757.06
# [93]	cv_agg's rmse: 108507 + 3758.49
# [94]	cv_agg's rmse: 108469 + 3756.63
# [95]	cv_agg's rmse: 108430 + 3715.84
# [96]	cv_agg's rmse: 108415 + 3710.91
# [97]	cv_agg's rmse: 108322 + 3687.64
# [98]	cv_agg's rmse: 108243 + 3759.49
# [99]	cv_agg's rmse: 108193 + 3745.1
# [100]	cv_agg's rmse: 108118 + 3697.36
# [101]	cv_agg's rmse: 108055 + 3695.4
# [102]	cv_agg's rmse: 107993 + 3683.46
# [103]	cv_agg's rmse: 107991 + 3681.97
# [104]	cv_agg's rmse: 107908 + 3712.38
# [105]	cv_agg's rmse: 107831 + 3750.91
# [106]	cv_agg's rmse: 107772 + 3755.8
# [107]	cv_agg's rmse: 107718 + 3750.86
# [108]	cv_agg's rmse: 107645 + 3757.63
# [109]	cv_agg's rmse: 107607 + 3759.96
# [110]	cv_agg's rmse: 107581 + 3751.94
# [111]	cv_agg's rmse: 107541 + 3766.87
# [112]	cv_agg's rmse: 107506 + 3795.2
# [113]	cv_agg's rmse: 107484 + 3826.07
# [114]	cv_agg's rmse: 107357 + 3839.61
# [115]	cv_agg's rmse: 107328 + 3837.77
# [116]	cv_agg's rmse: 107237 + 3874.09
# [117]	cv_agg's rmse: 107216 + 3861.03
# [118]	cv_agg's rmse: 107176 + 3882.38
# [119]	cv_agg's rmse: 107139 + 3896.04
# [120]	cv_agg's rmse: 107101 + 3885.21
# [121]	cv_agg's rmse: 107053 + 3894.66
# [122]	cv_agg's rmse: 107021 + 3887.6
# [123]	cv_agg's rmse: 107002 + 3880.16
# [124]	cv_agg's rmse: 106962 + 3897.52
# [125]	cv_agg's rmse: 106923 + 3933.9
# [126]	cv_agg's rmse: 106888 + 3926.29
# [127]	cv_agg's rmse: 106865 + 3939.31
# [128]	cv_agg's rmse: 106827 + 3961
# [129]	cv_agg's rmse: 106736 + 3882.47
# [130]	cv_agg's rmse: 106694 + 3871.07
# [131]	cv_agg's rmse: 106664 + 3860.22
# [132]	cv_agg's rmse: 106557 + 3762.29
# [133]	cv_agg's rmse: 106466 + 3731.38
# [134]	cv_agg's rmse: 106430 + 3719.72
# [135]	cv_agg's rmse: 106371 + 3706.58
# [136]	cv_agg's rmse: 106332 + 3713.54
# [137]	cv_agg's rmse: 106305 + 3690.31
# [138]	cv_agg's rmse: 106230 + 3680.25
# [139]	cv_agg's rmse: 106157 + 3643.47
# [140]	cv_agg's rmse: 106082 + 3642
# [141]	cv_agg's rmse: 106052 + 3626.84
# [142]	cv_agg's rmse: 106039 + 3621.23
# [143]	cv_agg's rmse: 105990 + 3625.77
# [144]	cv_agg's rmse: 105894 + 3604.59
# [145]	cv_agg's rmse: 105816 + 3565.98
# [146]	cv_agg's rmse: 105777 + 3551.54
# [147]	cv_agg's rmse: 105732 + 3530.8
# [148]	cv_agg's rmse: 105703 + 3524.05
# [149]	cv_agg's rmse: 105623 + 3455.82
# [150]	cv_agg's rmse: 105577 + 3437.19
# [151]	cv_agg's rmse: 105513 + 3441.01
# [152]	cv_agg's rmse: 105361 + 3452.71
# [153]	cv_agg's rmse: 105322 + 3483.25
# [154]	cv_agg's rmse: 105264 + 3466.76
# [155]	cv_agg's rmse: 105202 + 3488.43
# [156]	cv_agg's rmse: 105155 + 3451.75
# [157]	cv_agg's rmse: 105106 + 3437.22
# [158]	cv_agg's rmse: 105063 + 3413.34
# [159]	cv_agg's rmse: 105034 + 3433.91
# [160]	cv_agg's rmse: 104988 + 3408.05
# [161]	cv_agg's rmse: 104973 + 3394.35
# [162]	cv_agg's rmse: 104959 + 3397.21
# [163]	cv_agg's rmse: 104882 + 3428.25
# [164]	cv_agg's rmse: 104843 + 3424.29
# [165]	cv_agg's rmse: 104798 + 3431.12
# [166]	cv_agg's rmse: 104755 + 3436.67
# [167]	cv_agg's rmse: 104677 + 3349.96
# [168]	cv_agg's rmse: 104612 + 3357.91
# [169]	cv_agg's rmse: 104599 + 3329.52
# [170]	cv_agg's rmse: 104575 + 3341.21
# [171]	cv_agg's rmse: 104546 + 3334.22
# [172]	cv_agg's rmse: 104483 + 3363.46
# [173]	cv_agg's rmse: 104455 + 3352.96
# [174]	cv_agg's rmse: 104454 + 3355.8
# [175]	cv_agg's rmse: 104417 + 3332.69
# [176]	cv_agg's rmse: 104349 + 3356.32
# [177]	cv_agg's rmse: 104311 + 3315.98
# [178]	cv_agg's rmse: 104285 + 3300.5
# [179]	cv_agg's rmse: 104256 + 3317.58
# [180]	cv_agg's rmse: 104197 + 3333.91
# [181]	cv_agg's rmse: 104180 + 3319.87
# [182]	cv_agg's rmse: 104135 + 3341.82
# [183]	cv_agg's rmse: 104118 + 3338.3
# [184]	cv_agg's rmse: 104077 + 3345.75
# [185]	cv_agg's rmse: 104027 + 3335.54
# [186]	cv_agg's rmse: 104008 + 3336
# [187]	cv_agg's rmse: 103955 + 3329.58
# [188]	cv_agg's rmse: 103918 + 3330.77
# [189]	cv_agg's rmse: 103896 + 3318.81
# [190]	cv_agg's rmse: 103822 + 3313.04
# [191]	cv_agg's rmse: 103804 + 3323.41
# [192]	cv_agg's rmse: 103724 + 3340.85
# [193]	cv_agg's rmse: 103692 + 3342.31
# [194]	cv_agg's rmse: 103642 + 3368
# [195]	cv_agg's rmse: 103619 + 3348.61
# [196]	cv_agg's rmse: 103566 + 3394.58
# [197]	cv_agg's rmse: 103508 + 3387.11
# [198]	cv_agg's rmse: 103453 + 3354.46
# [199]	cv_agg's rmse: 103411 + 3322.29
# [200]	cv_agg's rmse: 103359 + 3394.75
# [201]	cv_agg's rmse: 103330 + 3370.28
# [202]	cv_agg's rmse: 103292 + 3395.43
# [203]	cv_agg's rmse: 103277 + 3415.42
# [204]	cv_agg's rmse: 103265 + 3405.52
# [205]	cv_agg's rmse: 103256 + 3395.81
# [206]	cv_agg's rmse: 103203 + 3408.01
# [207]	cv_agg's rmse: 103160 + 3411.36
# [208]	cv_agg's rmse: 103108 + 3381.21
# [209]	cv_agg's rmse: 103095 + 3383.82
# [210]	cv_agg's rmse: 103060 + 3365.78
# [211]	cv_agg's rmse: 103018 + 3332.59
# [212]	cv_agg's rmse: 103000 + 3327.19
# [213]	cv_agg's rmse: 102983 + 3339.01
# [214]	cv_agg's rmse: 102937 + 3366.6
# [215]	cv_agg's rmse: 102920 + 3351.95
# [216]	cv_agg's rmse: 102863 + 3358.1
# [217]	cv_agg's rmse: 102796 + 3334.04
# [218]	cv_agg's rmse: 102753 + 3353.75
# [219]	cv_agg's rmse: 102704 + 3351.46
# [220]	cv_agg's rmse: 102666 + 3339.92
# [221]	cv_agg's rmse: 102621 + 3332.14
# [222]	cv_agg's rmse: 102599 + 3343.09
# [223]	cv_agg's rmse: 102573 + 3334.6
# [224]	cv_agg's rmse: 102525 + 3303.09
# [225]	cv_agg's rmse: 102505 + 3298.84
# [226]	cv_agg's rmse: 102495 + 3297.07
# [227]	cv_agg's rmse: 102467 + 3316.04
# [228]	cv_agg's rmse: 102435 + 3310.8
# [229]	cv_agg's rmse: 102415 + 3308.99
# [230]	cv_agg's rmse: 102396 + 3285.82
# [231]	cv_agg's rmse: 102391 + 3283.5
# [232]	cv_agg's rmse: 102339 + 3309.12
# [233]	cv_agg's rmse: 102295 + 3312.79
# [234]	cv_agg's rmse: 102272 + 3320.81
# [235]	cv_agg's rmse: 102248 + 3350.76
# [236]	cv_agg's rmse: 102164 + 3355.85
# [237]	cv_agg's rmse: 102148 + 3368.91
# [238]	cv_agg's rmse: 102127 + 3348.54
# [239]	cv_agg's rmse: 102105 + 3351.65
# [240]	cv_agg's rmse: 102076 + 3351.57
# [241]	cv_agg's rmse: 102010 + 3328.41
# [242]	cv_agg's rmse: 101966 + 3343.61
# [243]	cv_agg's rmse: 101893 + 3347.81
# [244]	cv_agg's rmse: 101828 + 3365.35
# [245]	cv_agg's rmse: 101773 + 3341.43
# [246]	cv_agg's rmse: 101760 + 3338.13
# [247]	cv_agg's rmse: 101703 + 3338.84
# [248]	cv_agg's rmse: 101662 + 3342.48
# [249]	cv_agg's rmse: 101618 + 3366.74
# [250]	cv_agg's rmse: 101539 + 3348.55
# [251]	cv_agg's rmse: 101529 + 3347.17
# [252]	cv_agg's rmse: 101520 + 3348.84
# [253]	cv_agg's rmse: 101500 + 3310.19
# [254]	cv_agg's rmse: 101457 + 3342.15
# [255]	cv_agg's rmse: 101431 + 3366.52
# [256]	cv_agg's rmse: 101420 + 3357.76
# [257]	cv_agg's rmse: 101407 + 3351.31
# [258]	cv_agg's rmse: 101394 + 3362.38
# [259]	cv_agg's rmse: 101368 + 3346.2
# [260]	cv_agg's rmse: 101347 + 3353.46
# [261]	cv_agg's rmse: 101334 + 3341.66
# [262]	cv_agg's rmse: 101328 + 3343.98
# [263]	cv_agg's rmse: 101313 + 3330.08
# [264]	cv_agg's rmse: 101272 + 3334.31
# [265]	cv_agg's rmse: 101251 + 3335.62
# [266]	cv_agg's rmse: 101210 + 3297.21
# [267]	cv_agg's rmse: 101178 + 3310.73
# [268]	cv_agg's rmse: 101157 + 3313.31
# [269]	cv_agg's rmse: 101148 + 3319.25
# [270]	cv_agg's rmse: 101117 + 3323.43
# [271]	cv_agg's rmse: 101082 + 3291.03
# [272]	cv_agg's rmse: 101058 + 3268.32
# [273]	cv_agg's rmse: 101026 + 3283.12
# [274]	cv_agg's rmse: 100975 + 3288.01
# [275]	cv_agg's rmse: 100948 + 3309.18
# [276]	cv_agg's rmse: 100912 + 3331.39
# [277]	cv_agg's rmse: 100887 + 3323.94
# [278]	cv_agg's rmse: 100837 + 3328.03
# [279]	cv_agg's rmse: 100782 + 3319.4
# [280]	cv_agg's rmse: 100730 + 3335.36
# [281]	cv_agg's rmse: 100672 + 3369.12
# [282]	cv_agg's rmse: 100645 + 3367.95
# [283]	cv_agg's rmse: 100613 + 3366.36
# [284]	cv_agg's rmse: 100566 + 3367
# [285]	cv_agg's rmse: 100530 + 3381.45
# [286]	cv_agg's rmse: 100486 + 3417.01
# [287]	cv_agg's rmse: 100461 + 3431.19
# [288]	cv_agg's rmse: 100426 + 3412.61
# [289]	cv_agg's rmse: 100409 + 3379.26
# [290]	cv_agg's rmse: 100383 + 3383.42
# [291]	cv_agg's rmse: 100382 + 3383.31
# [292]	cv_agg's rmse: 100385 + 3385.52
# [293]	cv_agg's rmse: 100379 + 3385.64
# [294]	cv_agg's rmse: 100354 + 3368.79
# [295]	cv_agg's rmse: 100351 + 3375.09
# [296]	cv_agg's rmse: 100334 + 3362.18
# [297]	cv_agg's rmse: 100316 + 3360
# [298]	cv_agg's rmse: 100278 + 3386.54
# [299]	cv_agg's rmse: 100249 + 3406.54
# [300]	cv_agg's rmse: 100213 + 3411.82
# [301]	cv_agg's rmse: 100201 + 3413.44
# [302]	cv_agg's rmse: 100178 + 3406.29
# [303]	cv_agg's rmse: 100152 + 3425.58
# [304]	cv_agg's rmse: 100108 + 3420.21
# [305]	cv_agg's rmse: 100085 + 3432.44
# [306]	cv_agg's rmse: 100061 + 3445.8
# [307]	cv_agg's rmse: 100042 + 3450.29
# [308]	cv_agg's rmse: 100015 + 3467.12
# [309]	cv_agg's rmse: 99988.8 + 3488.17
# [310]	cv_agg's rmse: 99905.5 + 3502.49
# [311]	cv_agg's rmse: 99831.7 + 3540.86
# [312]	cv_agg's rmse: 99807.8 + 3529.53
# [313]	cv_agg's rmse: 99745.8 + 3522.24
# [314]	cv_agg's rmse: 99732.6 + 3533.2
# [315]	cv_agg's rmse: 99710.2 + 3536.71
# [316]	cv_agg's rmse: 99705.4 + 3540.28
# [317]	cv_agg's rmse: 99663.7 + 3548.18
# [318]	cv_agg's rmse: 99630.3 + 3554.79
# [319]	cv_agg's rmse: 99589 + 3541.98
# [320]	cv_agg's rmse: 99573.8 + 3519.39
# [321]	cv_agg's rmse: 99540.5 + 3486.13
# [322]	cv_agg's rmse: 99521.1 + 3467.04
# [323]	cv_agg's rmse: 99484 + 3471.58
# [324]	cv_agg's rmse: 99462.5 + 3475.49
# [325]	cv_agg's rmse: 99429.2 + 3474.61
# [326]	cv_agg's rmse: 99417.2 + 3473.42
# [327]	cv_agg's rmse: 99383.6 + 3464.33
# [328]	cv_agg's rmse: 99356.5 + 3498.47
# [329]	cv_agg's rmse: 99339.8 + 3514.6
# [330]	cv_agg's rmse: 99306.7 + 3517.46
# [331]	cv_agg's rmse: 99263.5 + 3499.98
# [332]	cv_agg's rmse: 99219.7 + 3473.7
# [333]	cv_agg's rmse: 99203.2 + 3458.16
# [334]	cv_agg's rmse: 99179.6 + 3443.63
# [335]	cv_agg's rmse: 99140.8 + 3424.65
# [336]	cv_agg's rmse: 99093.8 + 3417.05
# [337]	cv_agg's rmse: 99071.1 + 3412.92
# [338]	cv_agg's rmse: 99046.7 + 3408.58
# [339]	cv_agg's rmse: 99046.4 + 3409.34
# [340]	cv_agg's rmse: 99006.7 + 3397.17
# [341]	cv_agg's rmse: 98966.4 + 3410.75
# [342]	cv_agg's rmse: 98961.7 + 3392.04
# [343]	cv_agg's rmse: 98931.8 + 3411.61
# [344]	cv_agg's rmse: 98912.2 + 3412.63
# [345]	cv_agg's rmse: 98898.4 + 3420.78
# [346]	cv_agg's rmse: 98885.6 + 3432.66
# [347]	cv_agg's rmse: 98861.2 + 3443.8
# [348]	cv_agg's rmse: 98839.9 + 3416.09
# [349]	cv_agg's rmse: 98818.9 + 3424.21
# [350]	cv_agg's rmse: 98790.9 + 3444.07
# [351]	cv_agg's rmse: 98757.7 + 3450.54
# [352]	cv_agg's rmse: 98742.9 + 3447.28
# [353]	cv_agg's rmse: 98723.6 + 3457.57
# [354]	cv_agg's rmse: 98690.6 + 3455.1
# [355]	cv_agg's rmse: 98672.2 + 3455.68
# [356]	cv_agg's rmse: 98626.7 + 3486.78
# [357]	cv_agg's rmse: 98620.7 + 3491.89
# [358]	cv_agg's rmse: 98613.7 + 3500.71
# [359]	cv_agg's rmse: 98601.8 + 3507.79
# [360]	cv_agg's rmse: 98590 + 3525.18
# [361]	cv_agg's rmse: 98560.2 + 3503.66
# [362]	cv_agg's rmse: 98545.2 + 3513.15
# [363]	cv_agg's rmse: 98526.8 + 3512.39
# [364]	cv_agg's rmse: 98510.8 + 3497.73
# [365]	cv_agg's rmse: 98492.9 + 3504.67
# [366]	cv_agg's rmse: 98447.9 + 3465.41
# [367]	cv_agg's rmse: 98433.4 + 3471.19
# [368]	cv_agg's rmse: 98393.6 + 3461.88
# [369]	cv_agg's rmse: 98366.3 + 3468.24
# [370]	cv_agg's rmse: 98337.9 + 3454.38
# [371]	cv_agg's rmse: 98326.4 + 3447.58
# [372]	cv_agg's rmse: 98285.7 + 3427.84
# [373]	cv_agg's rmse: 98274.7 + 3433.36
# [374]	cv_agg's rmse: 98259.9 + 3430.59
# [375]	cv_agg's rmse: 98217.6 + 3409.68
# [376]	cv_agg's rmse: 98208.8 + 3413.34
# [377]	cv_agg's rmse: 98138.8 + 3397.87
# [378]	cv_agg's rmse: 98120.6 + 3397.47
# [379]	cv_agg's rmse: 98106.7 + 3389.87
# [380]	cv_agg's rmse: 98100.8 + 3399.36
# [381]	cv_agg's rmse: 98090.9 + 3398.48
# [382]	cv_agg's rmse: 98074.2 + 3406.19
# [383]	cv_agg's rmse: 98060.3 + 3417.77
# [384]	cv_agg's rmse: 98038.8 + 3424.86
# [385]	cv_agg's rmse: 98022 + 3424.43
# [386]	cv_agg's rmse: 98019.5 + 3424.34
# [387]	cv_agg's rmse: 98014.3 + 3416.97
# [388]	cv_agg's rmse: 97993 + 3430.16
# [389]	cv_agg's rmse: 97991.6 + 3432.07
# [390]	cv_agg's rmse: 97964.6 + 3410.11
# [391]	cv_agg's rmse: 97960.6 + 3402.25
# [392]	cv_agg's rmse: 97953.5 + 3406.96
# [393]	cv_agg's rmse: 97927.8 + 3424.45
# [394]	cv_agg's rmse: 97916.6 + 3409.44
# [395]	cv_agg's rmse: 97876.7 + 3404.35
# [396]	cv_agg's rmse: 97863.4 + 3403.99
# [397]	cv_agg's rmse: 97841.3 + 3379.57
# [398]	cv_agg's rmse: 97834 + 3388.71
# [399]	cv_agg's rmse: 97778.9 + 3381.44
# [400]	cv_agg's rmse: 97770.1 + 3390.39
# [401]	cv_agg's rmse: 97753.6 + 3388.17
# [402]	cv_agg's rmse: 97712.6 + 3428.32
# [403]	cv_agg's rmse: 97684.1 + 3441.91
# [404]	cv_agg's rmse: 97682.8 + 3449.84
# [405]	cv_agg's rmse: 97643.5 + 3429.44
# [406]	cv_agg's rmse: 97607.1 + 3414.92
# [407]	cv_agg's rmse: 97580.9 + 3409.35
# [408]	cv_agg's rmse: 97541.3 + 3423.68
# [409]	cv_agg's rmse: 97516.2 + 3408.73
# [410]	cv_agg's rmse: 97504.9 + 3428.18
# [411]	cv_agg's rmse: 97500.7 + 3430.15
# [412]	cv_agg's rmse: 97494.8 + 3435.18
# [413]	cv_agg's rmse: 97466.7 + 3440.86
# [414]	cv_agg's rmse: 97456.4 + 3444.27
# [415]	cv_agg's rmse: 97426.2 + 3471.27
# [416]	cv_agg's rmse: 97406 + 3487.9
# [417]	cv_agg's rmse: 97383.2 + 3509.6
# [418]	cv_agg's rmse: 97365.5 + 3500.58
# [419]	cv_agg's rmse: 97355.5 + 3508.94
# [420]	cv_agg's rmse: 97318.3 + 3537.36
# [421]	cv_agg's rmse: 97293.2 + 3538.11
# [422]	cv_agg's rmse: 97246.7 + 3546.54
# [423]	cv_agg's rmse: 97189.9 + 3557.87
# [424]	cv_agg's rmse: 97175.5 + 3549.17
# [425]	cv_agg's rmse: 97156.6 + 3546.19
# [426]	cv_agg's rmse: 97139.6 + 3553.57
# [427]	cv_agg's rmse: 97122.5 + 3554.79
# [428]	cv_agg's rmse: 97106.7 + 3563.52
# [429]	cv_agg's rmse: 97094.6 + 3541.52
# [430]	cv_agg's rmse: 97071.5 + 3547.71
# [431]	cv_agg's rmse: 97050.2 + 3541
# [432]	cv_agg's rmse: 97036.6 + 3539.58
# [433]	cv_agg's rmse: 97014.6 + 3528.03
# [434]	cv_agg's rmse: 96984.9 + 3509.5
# [435]	cv_agg's rmse: 96968.7 + 3499.89
# [436]	cv_agg's rmse: 96956.6 + 3492.77
# [437]	cv_agg's rmse: 96946.1 + 3475.52
# [438]	cv_agg's rmse: 96943.8 + 3474.01
# [439]	cv_agg's rmse: 96921.6 + 3480.86
# [440]	cv_agg's rmse: 96885.9 + 3474.73
# [441]	cv_agg's rmse: 96853 + 3467.16
# [442]	cv_agg's rmse: 96831.1 + 3465.15
# [443]	cv_agg's rmse: 96812 + 3464.82
# [444]	cv_agg's rmse: 96798.1 + 3442.1
# [445]	cv_agg's rmse: 96771.2 + 3418.38
# [446]	cv_agg's rmse: 96772.4 + 3426.5
# [447]	cv_agg's rmse: 96709.1 + 3470
# [448]	cv_agg's rmse: 96695.2 + 3481.41
# [449]	cv_agg's rmse: 96673.2 + 3459.07
# [450]	cv_agg's rmse: 96655.8 + 3438.24
# [451]	cv_agg's rmse: 96649.4 + 3436.39
# [452]	cv_agg's rmse: 96653.3 + 3439.8
# [453]	cv_agg's rmse: 96643 + 3450.74
# [454]	cv_agg's rmse: 96621.3 + 3451.22
# [455]	cv_agg's rmse: 96613.8 + 3453.05
# [456]	cv_agg's rmse: 96591.1 + 3448.67
# [457]	cv_agg's rmse: 96576.7 + 3439.44
# [458]	cv_agg's rmse: 96561.9 + 3446.55
# [459]	cv_agg's rmse: 96546 + 3430.31
# [460]	cv_agg's rmse: 96535.5 + 3423.9
# [461]	cv_agg's rmse: 96512 + 3431.77
# [462]	cv_agg's rmse: 96468.9 + 3448.66
# [463]	cv_agg's rmse: 96422.7 + 3443.72
# [464]	cv_agg's rmse: 96409.7 + 3431.16
# [465]	cv_agg's rmse: 96401.6 + 3424.01
# [466]	cv_agg's rmse: 96400 + 3424.3
# [467]	cv_agg's rmse: 96399.7 + 3418.14
# [468]	cv_agg's rmse: 96371 + 3428.51
# [469]	cv_agg's rmse: 96331.5 + 3444.01
# [470]	cv_agg's rmse: 96311.9 + 3446.24
# [471]	cv_agg's rmse: 96289 + 3415.35
# [472]	cv_agg's rmse: 96272.7 + 3442.68
# [473]	cv_agg's rmse: 96260.6 + 3435.21
# [474]	cv_agg's rmse: 96228.3 + 3438.89
# [475]	cv_agg's rmse: 96217.3 + 3435.54
# [476]	cv_agg's rmse: 96193.9 + 3425.64
# [477]	cv_agg's rmse: 96134.1 + 3414.91
# [478]	cv_agg's rmse: 96099 + 3410.9
# [479]	cv_agg's rmse: 96086.5 + 3416.56
# [480]	cv_agg's rmse: 96074 + 3420.58
# [481]	cv_agg's rmse: 96050.2 + 3403.51
# [482]	cv_agg's rmse: 96025.3 + 3397.38
# [483]	cv_agg's rmse: 96021.3 + 3396.65
# [484]	cv_agg's rmse: 95984.9 + 3410.34
# [485]	cv_agg's rmse: 95958.7 + 3408.79
# [486]	cv_agg's rmse: 95951.4 + 3406.39
# [487]	cv_agg's rmse: 95931.2 + 3407.5
# [488]	cv_agg's rmse: 95915 + 3397.33
# [489]	cv_agg's rmse: 95900.2 + 3400.89
# [490]	cv_agg's rmse: 95856.9 + 3423.76
# [491]	cv_agg's rmse: 95844.6 + 3422.38
# [492]	cv_agg's rmse: 95829.1 + 3404.68
# [493]	cv_agg's rmse: 95823 + 3399.01
# [494]	cv_agg's rmse: 95803.2 + 3398.14
# [495]	cv_agg's rmse: 95780.9 + 3399.81
# [496]	cv_agg's rmse: 95771.3 + 3408.97
# [497]	cv_agg's rmse: 95761.2 + 3412.46
# [498]	cv_agg's rmse: 95744.9 + 3400.96
# [499]	cv_agg's rmse: 95739.4 + 3401.14
# [500]	cv_agg's rmse: 95725.3 + 3402.38

# %%
# params
print('Current parameters:\n', params)
print('\nBest num_boost_round:', len(cv_results['rmse-mean']))
print('Best CV score:', cv_results['rmse-mean'][-1])
# Out:
# Current parameters:
#  {'boosting_type': 'gbdt', 'objective': 'regression', 'metric': {'rmse'}, 'num_leave': 100}
#
# Best num_boost_round: 500
# Best CV score: 95725.27285569778

# %%
num_boost_rounds_lgb=len(cv_results['rmse-mean'])
model_lgb = lgb.train(params, dftrainLGB, num_boost_round=num_boost_rounds_lgb)

# %%
y_pred_lgb = model_lgb.predict(x_test)
y_pred_lgb[y_pred_lgb < 0] = 0

# %%
lgb_rmsle = rmsle(list(y_test), list(y_pred_lgb))

# %%
print('lightgbm RMSLE Score [num_of_leaves] is {}'.format(lgb_rmsle))
# Out:
# lightgbm RMSLE Score [num_of_leaves] is 2.515375561461128

# %% [markdown]
# ### Parameter Tuning [grid search]

# %%
import gc
gc.collect()
# Out:
# 7

# %%
# x_train

# %%
from sklearn.model_selection import GridSearchCV
estimator = lgb.LGBMRegressor(num_leaves=31)

param_grid = {
    'learning_rate': [0.01, 0.1, 0.25],
    'num_leaves': [10, 30, 50],
    'max_depth': [-1, 5, 10]
}

gbm = GridSearchCV(estimator, param_grid)
gbm.fit(x_train, y_train)
# Out:
# /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/sklearn/model_selection/_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)
# GridSearchCV(cv='warn', error_score='raise-deprecating',
#              estimator=LGBMRegressor(boosting_type='gbdt', class_weight=None,
#                                      colsample_bytree=1.0,
#                                      importance_type='split', learning_rate=0.1,
#                                      max_depth=-1, min_child_samples=20,
#                                      min_child_weight=0.001, min_split_gain=0.0,
#                                      n_estimators=100, n_jobs=-1, num_leaves=31,
#                                      objective=None, random_state=None,
#                                      reg_alpha=0.0, reg_lambda=0.0, silent=True,
#                                      subsample=1.0, subsample_for_bin=200000,
#                                      subsample_freq=0),
#              iid='warn', n_jobs=None,
#              param_grid={'learning_rate': [0.01, 0.1, 0.25],
#                          'max_depth': [-1, 5, 10], 'num_leaves': [10, 30, 50]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=0)

# %%
gbm.best_params_
# Out:
# {'learning_rate': 0.25, 'max_depth': -1, 'num_leaves': 50}

# %%
print('Best parameters found by grid search are: ', gbm.best_params_)
# Out:
# Best parameters found by grid search are:  {'learning_rate': 0.25, 'max_depth': -1, 'num_leaves': 50}

# %% [markdown]
# ### Default setting LightGBM model

# %%
lgb_model = lgb.LGBMRegressor()

# %%
lgb_model
# Out:
# LGBMRegressor(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#               importance_type='split', learning_rate=0.1, max_depth=-1,
#               min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#               n_estimators=100, n_jobs=-1, num_leaves=31, objective=None,
#               random_state=None, reg_alpha=0.0, reg_lambda=0.0, silent=True,
#               subsample=1.0, subsample_for_bin=200000, subsample_freq=0)

# %%
# x_train.head()

# %%
lgb_model.set_params(
    n_estimators = 10000,
    learning_rate = 0.25, 
    max_depth = -1, 
    num_leaves = 50
)
# Out:
# LGBMRegressor(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#               importance_type='split', learning_rate=0.25, max_depth=-1,
#               min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#               n_estimators=10000, n_jobs=-1, num_leaves=50, objective=None,
#               random_state=None, reg_alpha=0.0, reg_lambda=0.0, silent=True,
#               subsample=1.0, subsample_for_bin=200000, subsample_freq=0)

# %%
x_train.columns
# Out:
# Index(['square_feet', 'beaufort_scale', 'precip_depth_1_hr', 'dew_temperature',
#        'air_temperature', 'hour_sin', 'hour_cos', 'sea_level_pressure',
#        'wind_direction', 'wind_speed', 'meter_0', 'meter_1', 'meter_2',
#        'meter_3', 'site_id_0', 'site_id_2', 'site_id_3', 'site_id_4',
#        'site_id_6', 'site_id_7', 'site_id_8', 'site_id_9', 'site_id_10',
#        'site_id_11', 'site_id_13', 'site_id_14', 'site_id_15',
#        'primary_use_Education', 'primary_use_Entertainment/public assembly',
#        'primary_use_Food sales and service', 'primary_use_Healthcare',
#        'primary_use_Lodging/residential',
#        'primary_use_Manufacturing/industrial', 'primary_use_Office',
#        'primary_use_Other', 'primary_use_Parking',
#        'primary_use_Public services', 'primary_use_Religious worship',
#        'primary_use_Retail', 'primary_use_Services',
#        'primary_use_Technology/science', 'primary_use_Utility',
#        'primary_use_Warehouse/storage', 'month_1', 'month_2', 'month_3',
#        'month_4', 'month_5', 'month_6', 'month_7', 'month_8', 'month_9',
#        'month_10', 'month_11', 'month_12', 'dayofweek_0', 'dayofweek_1',
#        'dayofweek_2', 'dayofweek_3', 'dayofweek_4', 'dayofweek_5',
#        'dayofweek_6'],
#       dtype='object')

# %%
lgb_model.fit(
    x_train, 
    y_train.values, 
    eval_metric='rmlse',
    eval_set=[(x_val, y_val)],
    verbose = True,
    early_stopping_rounds=500
)
# Out:
# [1]	valid_0's l2: 1.71127e+10
# Training until validation scores don't improve for 500 rounds
# [2]	valid_0
# [2683]	valid_0's l2: 1.94057e+09
# [2684]	valid_0's l2: 1.94058e+09
# [2685]	valid_0's l2: 1.94052e+09
# [2686]	valid_0's l2: 1.94015e+09
# [2687]	valid_0's l2: 1.94015e+09
# [2688]	valid_0's l2: 1.94015e+09
# [2689]	valid_0's l2: 1.9401e+09
# [2690]	valid_0's l2: 1.93998e+09
# [2691]	valid_0's l2: 1.93991e+09
# [2692]	valid_0's l2: 1.9399e+09
# [2693]	valid_0's l2: 1.93964e+09
# [2694]	valid_0's l2: 1.93963e+09
# [2695]	valid_0's l2: 1.93963e+09
# [2696]	valid_0's l2: 1.93964e+09
# [2697]	valid_0's l2: 1.93967e+09
# [2698]	valid_0's l2: 1.93966e+09
# [2699]	valid_0's l2: 1.93966e+09
# [2700]	valid_0's l2: 1.93966e+09
# [2701]	valid_0's l2: 1.93966e+09
# [2702]	valid_0's l2: 1.93971e+09
# [2703]	valid_0's l2: 1.93969e+09
# [2704]	valid_0's l2: 1.93969e+09
# [2705]	valid_0's l2: 1.93969e+09
# [2706]	valid_0's l2: 1.93962e+09
# [2707]	valid_0's l2: 1.93965e+09
# [2708]	valid_0's l2: 1.93965e+09
# [2709]	valid_0's l2: 1.93953e+09
# [2710]	valid_0's l2: 1.93953e+09
# [2711]	valid_0's l2: 1.93952e+09
# Early stopping, best iteration is:
# [2211]	valid_0's l2: 1.93928e+09
# LGBMRegressor(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#               importance_type='split', learning_rate=0.25, max_depth=-1,
#               min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#               n_estimators=10000, n_jobs=-1, num_leaves=50, objective=None,
#               random_state=None, reg_alpha=0.0, reg_lambda=0.0, silent=True,
#               subsample=1.0, subsample_for_bin=200000, subsample_freq=0)

# %%
y_pred_lgb = lgb_model.predict(x_test)
y_pred_lgb[y_pred_lgb < 0] = 0

# %%
lgb_rmsle = rmsle(list(y_test), list(y_pred_lgb))

# %%
print('lightgbm RMSLE Score is {}'.format(lgb_rmsle))
# Out:
# lightgbm RMSLE Score is 1.9625795828689219

# %%
joblib.dump(lgb_model, 'model/lgb_model.pkl')
# Out:
# ['model/lgb_model.pkl']

# %% [markdown]
# ### Predicting RMSLE on submission file

# %%
from keras.models import load_model
# Out:
# Using TensorFlow backend.

# %%
# lgb_model = load_model('model/lgb_model.pkl')

# %%
x_train.shape, x_submit.shape, x_test.shape
# Out:
# ((9576523, 62), (41697600, 62), (2992664, 62))

# %%
x_train.columns, x_submit.columns
# Out:
# (Index(['square_feet', 'beaufort_scale', 'precip_depth_1_hr', 'dew_temperature',
#         'air_temperature', 'hour_sin', 'hour_cos', 'sea_level_pressure',
#         'wind_direction', 'wind_speed', 'meter_0', 'meter_1', 'meter_2',
#         'meter_3', 'site_id_0', 'site_id_2', 'site_id_3', 'site_id_4',
#         'site_id_6', 'site_id_7', 'site_id_8', 'site_id_9', 'site_id_10',
#         'site_id_11', 'site_id_13', 'site_id_14', 'site_id_15',
#         'primary_use_Education', 'primary_use_Entertainment/public assembly',
#         'primary_use_Food sales and service', 'primary_use_Healthcare',
#         'primary_use_Lodging/residential',
#         'primary_use_Manufacturing/industrial', 'primary_use_Office',
#         'primary_use_Other', 'primary_use_Parking',
#         'primary_use_Public services', 'primary_use_Religious worship',
#         'primary_use_Retail', 'primary_use_Services',
#         'primary_use_Technology/science', 'primary_use_Utility',
#         'primary_use_Warehouse/storage', 'month_1', 'month_2', 'month_3',
#         'month_4', 'month_5', 'month_6', 'month_7', 'month_8', 'month_9',
#         'month_10', 'month_11', 'month_12', 'dayofweek_0', 'dayofweek_1',
#         'dayofweek_2', 'dayofweek_3', 'dayofweek_4', 'dayofweek_5',
#         'dayofweek_6'],
#        dtype='object'),
#  Index(['square_feet', 'beaufort_scale', 'precip_depth_1_hr', 'dew_temperature',
#         'air_temperature', 'hour_sin', 'hour_cos', 'sea_level_pressure',
#         'wind_direction', 'wind_speed', 'meter_0', 'meter_1', 'meter_2',
#         'meter_3', 'site_id_0', 'site_id_2', 'site_id_3', 'site_id_4',
#         'site_id_6', 'site_id_7', 'site_id_8', 'site_id_9', 'site_id_10',
#         'site_id_11', 'site_id_13', 'site_id_14', 'site_id_15',
#         'primary_use_Education', 'primary_use_Entertainment/public assembly',
#         'primary_use_Food sales and service', 'primary_use_Healthcare',
#         'primary_use_Lodging/residential',
#         'primary_use_Manufacturing/industrial', 'primary_use_Office',
#         'primary_use_Other', 'primary_use_Parking',
#         'primary_use_Public services', 'primary_use_Religious worship',
#         'primary_use_Retail', 'primary_use_Services',
#         'primary_use_Technology/science', 'primary_use_Utility',
#         'primary_use_Warehouse/storage', 'month_1', 'month_2', 'month_3',
#         'month_4', 'month_5', 'month_6', 'month_7', 'month_8', 'month_9',
#         'month_10', 'month_11', 'month_12', 'dayofweek_0', 'dayofweek_1',
#         'dayofweek_2', 'dayofweek_3', 'dayofweek_4', 'dayofweek_5',
#         'dayofweek_6'],
#        dtype='object'))

# %%
x_submit.columns
# Out:
# Index(['square_feet', 'beaufort_scale', 'precip_depth_1_hr', 'dew_temperature',
#        'air_temperature', 'hour_sin', 'hour_cos', 'sea_level_pressure',
#        'wind_direction', 'wind_speed', 'meter_0', 'meter_1', 'meter_2',
#        'meter_3', 'site_id_0', 'site_id_2', 'site_id_3', 'site_id_4',
#        'site_id_6', 'site_id_7', 'site_id_8', 'site_id_9', 'site_id_10',
#        'site_id_11', 'site_id_13', 'site_id_14', 'site_id_15',
#        'primary_use_Education', 'primary_use_Entertainment/public assembly',
#        'primary_use_Food sales and service', 'primary_use_Healthcare',
#        'primary_use_Lodging/residential',
#        'primary_use_Manufacturing/industrial', 'primary_use_Office',
#        'primary_use_Other', 'primary_use_Parking',
#        'primary_use_Public services', 'primary_use_Religious worship',
#        'primary_use_Retail', 'primary_use_Services',
#        'primary_use_Technology/science', 'primary_use_Utility',
#        'primary_use_Warehouse/storage', 'month_1', 'month_2', 'month_3',
#        'month_4', 'month_5', 'month_6', 'month_7', 'month_8', 'month_9',
#        'month_10', 'month_11', 'month_12', 'dayofweek_0', 'dayofweek_1',
#        'dayofweek_2', 'dayofweek_3', 'dayofweek_4', 'dayofweek_5',
#        'dayofweek_6'],
#       dtype='object')

# %%
# lgb_model = load_model('model/lgb_model.h5')

# %%
# 41697600/4, 41697600/4*2, 41697600/4*3, 41697600

# %%
# x_submit[:10424400].shape

# %%
y_pred_lgb = lgb_model.predict(x_submit)
y_pred_lgb[y_pred_lgb < 0] = 0

# %%
# y_pred_lgb_2 = lgb_model.predict(x_submit[10424400:20848800])
# y_pred_lgb_2[y_pred_lgb_2 < 0] = 0

# %%
# y_pred_lgb_3 = lgb_model.predict(x_submit[20848800:31273200])
# y_pred_lgb_3[y_pred_lgb_3 < 0] = 0

# %%
# y_pred_lgb_4 = lgb_model.predict(x_submit[31273200:])
# y_pred_lgb_4[y_pred_lgb_4 < 0] = 0

# %%
y_pred_lgb.shape
# Out:
# (41697600,)

# %%
df_test.shape
# Out:
# (41697600, 72)

# %%
# df_test.head()

# %%
df_test['meter_reading'] = y_pred_lgb

# %%
df_test.head()
# Out:
#    row_id  building_id  timestamp  square_feet  air_temperature  \
# 0       0            0 2017-01-01     8.913550             17.8
# 1       1            1 2017-01-01     7.908387             17.8
# 2       2            2 2017-01-01     8.589700             17.8
# 3       3            3 2017-01-01    10.072597             17.8
# 4       4            4 2017-01-01    11.666565             17.8
#
#    dew_temperature  precip_depth_1_hr  sea_level_pressure  wind_direction  \
# 0             11.7                NaN              1021.5           100.0
# 1             11.7                NaN              1021.5           100.0
# 2             11.7                NaN              1021.5           100.0
# 3             11.7                NaN              1021.5           100.0
# 4             11.7                NaN              1021.5           100.0
#
#    wind_speed  ...  month_11  month_12  dayofweek_0  dayofweek_1  dayofweek_2  \
# 0         3.6  ...         0         0            0            0            0
# 1         3.6  ...         0         0            0            0            0
# 2         3.6  ...         0         0            0            0            0
# 3         3.6  ...         0         0            0            0            0
# 4         3.6  ...         0         0            0            0            0
#
#    dayofweek_3  dayofweek_4  dayofweek_5  dayofweek_6  meter_reading
# 0            0            0            0            1       0.000000
# 1            0            0            0            1       0.000000
# 2            0            0            0            1       0.000000
# 3            0            0            0            1       0.000000
# 4            0            0            0            1     237.484234
#
# [5 rows x 73 columns]

# %%
x_submit.shape
# Out:
# (41697600, 62)

# %%
df_submission.shape
# Out:
# (24936697, 2)

# %%
test_submission = pd.read_csv('data/test_submission_full.csv')
print(test_submission.shape)
# Out:
# (41697600, 2)

# %%
test_submission.head()
# Out:
#    row_id  meter_reading
# 0       0       2.331686
# 1       1       0.000000
# 2       2       2.331686
# 3       3      40.160470
# 4       4     359.384284

# %%
test_submission['meter_reading'] = df_test['meter_reading']

# %%
test_submission.shape
# Out:
# (41697600, 2)

# %%
test_submission.head()
# Out:
#    row_id  meter_reading
# 0       0       0.000000
# 1       1       0.000000
# 2       2       0.000000
# 3       3       0.000000
# 4       4     237.484234

# %%
# df_submission_test = pd.DataFrame([], columns = ['row_id', 'meter_reading'])
# df_submission_test['row_id'] = x_submit['row_id']
# df_submission_test['meter_reading'] = x_submit['meter_reading']
test_submission.to_csv('data/test_submission_full.csv', index=False)

# %% [markdown]
# ### Small LSTM

# %%
import numpy as np
import pandas as pd"tpw3487
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense, Dropout, Embedding, LSTM, GlobalMaxPooling1D, SpatialDropout1D
from keras.optimizers import RMSprop,Adam
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.callbacks import ModelCheckpoint
from keras import losses

# %%
x_train.shape, x_val.shape, x_test.shape

# %%
x_train = x_train.reshape(9576523, 1, 9)
x_val = x_val.reshape(2394131, 1, 9)
x_test = x_test.reshape(2992664, 1, 9)

# x_submit = x_submit.values
# x_submit = x_submit.reshape(24936697, 1, 9)

# %%
x_train.shape, x_val.shape, x_submit.shape

# %%
input_dim = (x_train.shape[1], x_train.shape[2])

# %%
callbacks = [EarlyStopping(monitor='val_loss', patience=15),
             ModelCheckpoint(filepath='simple_lstm_2.h5', monitor='val_loss', save_best_only=True)]

# %%
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.LSTM(units=30, return_sequences=True, input_shape=input_dim))
model.add(tf.keras.layers.LSTM(units=16, return_sequences=True))
model.add(tf.keras.layers.Dropout(0.8))
model.add(tf.keras.layers.Dense(1))
model.compile(optimizer=tf.keras.optimizers.Adam(clipvalue=1.0), 
              loss=losses.mean_squared_logarithmic_error)

# %%
model.summary()

# %%
model.fit(x_train, y_train, epochs=50, batch_size=1024, validation_data=(x_val, y_val), callbacks=callbacks)

# %%
y_pred_nn = model.predict(x_test)
y_pred_nn[y_pred_nn < 0] = 0

# %%
nn_rmsle = rmsle(list(y_test), list(y_pred_nn))

# %%
print('LSTM RMSLE Score is {}'.format(nn_rmsle))
# Out:
# LSTM RMSLE Score is 2.1848922221754057

# %%
model

# %%
x_test.shape, x_submit.shape
# Out:
# ((2992664, 1, 8), (24936697, 1, 8))

# %%
y_pred_nn_submit = model.predict(x_submit)
y_pred_nn_submit[y_pred_nn_submit < 0] = 0

# %%
df_submission.columns

# %%
df_submission['meter_reading'] = y_pred_nn_submit

# %%
df_submission.to_csv('data/test_submission.csv')

# %% [markdown]
# ### LSTM with weather variables

# %%
print(x_train.shape, x_val.shape, x_test.shape)
# Out:
# (9576523, 41) (2394131, 41) (2992664, 41)

# %%
x_train = x_train.reshape(9576523, 1, 41)
# x_val = x_val.reshape(2394131, 1, 41)
# x_test = x_test.reshape(2992664, 1, 41)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-226-5d0790b9f2bc> in <module>()
# ----> 1 x_train = x_train.reshape(9576523, 1, 41)
#       2 # x_val = x_val.reshape(2394131, 1, 41)
#       3 # x_test = x_test.reshape(2992664, 1, 41)
#
# ~/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'reshape'

# %%
callbacks = [EarlyStopping(monitor='val_loss', patience=15),
             ModelCheckpoint(filepath='simple_lstm_improved.h5', monitor='val_loss', save_best_only=True)]

# %%
model_2 = tf.keras.models.Sequential()
model_2.add(tf.keras.layers.LSTM(units=30, return_sequences=True, input_shape=(1, 9)))
model_2.add(tf.keras.layers.LSTM(units=32, return_sequences=True))
model_2.add(tf.keras.layers.Dropout(0.8))
model_2.add(tf.keras.layers.LSTM(units=16, return_sequences=True))
model_2.add(tf.keras.layers.Dropout(0.8))
model_2.add(tf.keras.layers.Dense(1))
model_2.compile(optimizer=tf.keras.optimizers.Adam(clipvalue=1.0), 
                loss=losses.mean_squared_logarithmic_error)
# Out:
# W1110 21:13:27.702513 140638866609984 nn_ops.py:4224] Large dropout rate: 0.8 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# W1110 21:13:27.924329 140638866609984 nn_ops.py:4224] Large dropout rate: 0.8 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.

# %%
model_2.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_4 (LSTM)                (None, 1, 30)             4800
# _________________________________________________________________
# lstm_5 (LSTM)                (None, 1, 32)             8064
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 1, 32)             0
# _________________________________________________________________
# lstm_6 (LSTM)                (None, 1, 16)             3136
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 1, 16)             0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1, 1)              17
# =================================================================
# Total params: 16,017
# Trainable params: 16,017
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_2.fit(x_train, y_train, epochs=50, batch_size=1024, validation_data=(x_val, y_val), callbacks=callbacks)
# Out:
# Train on 9576523 samples, validate on 2394131 samples
# Epoch 1/50
# 9576523/9576523 [==============================] - 167s 17us/sample - loss: 6.1944 - val_loss: 4.7847
# Epoch 2/50
# 9576523/9576523 [==============================] - 165s 17us/sample - loss: 5.0458 - val_loss: 4.7829
# Epoch 3/50
# 9576523/9576523 [==============================] - 165s 17us/sample - loss: 4.9381 - val_loss: 4.7837
# Epoch 4/50
# 9576523/9576523 [==============================] - 164s 17us/sample - loss: 4.8738 - val_loss: 4.7847
# Epoch 5/50
# 9576523/9576523 [==============================] - 164s 17us/sample - loss: 4.8333 - val_loss: 4.7846
# Epoch 6/50
# 9576523/9576523 [==============================] - 164s 17us/sample - loss: 4.8084 - val_loss: 4.7842
# Epoch 7/50
# 9576523/9576523 [==============================] - 165s 17us/sample - loss: 4.7940 - val_loss: 4.7840
# Epoch 8/50
# 9576523/9576523 [==============================] - 164s 17us/sample - loss: 4.7864 - val_loss: 4.7834
# Epoch 9/50
# 9576523/9576523 [==============================] - 164s 17us/sample - loss: 4.7828 - val_loss: 4.7830
# Epoch 10/50
# 9576523/9576523 [==============================] - 164s 17us/sample - loss: 4.7811 - val_loss: 4.7831
# Epoch 11/50
# 9576523/9576523 [==============================] - 164s 17us/sample - loss: 4.7804 - val_loss: 4.7829
# Epoch 12/50
# 9576523/9576523 [==============================] - 165s 17us/sample - loss: 4.7801 - val_loss: 4.7829
# Epoch 13/50
# 9576523/9576523 [==============================] - 164s 17us/sample - loss: 4.7799 - val_loss: 4.7829
# Epoch 14/50
# 9576523/9576523 [==============================] - 164s 17us/sample - loss: 4.7799 - val_loss: 4.7829
# Epoch 15/50
# 9576523/9576523 [==============================] - 165s 17us/sample - loss: 4.7798 - val_loss: 4.7829
# Epoch 16/50
# 9576523/9576523 [==============================] - 164s 17us/sample - loss: 4.7798 - val_loss: 4.7829
# Epoch 17/50
# 9576523/9576523 [==============================] - 164s 17us/sample - loss: 4.7798 - val_loss: 4.7829
# Epoch 18/50
# 9576523/9576523 [==============================] - 164s 17us/sample - loss: 4.7798 - val_loss: 4.7829
# Epoch 19/50
# 9576523/9576523 [==============================] - 163s 17us/sample - loss: 4.7798 - val_loss: 4.7829
# Epoch 20/50
# 9576523/9576523 [==============================] - 164s 17us/sample - loss: 4.7798 - val_loss: 4.7829
# Epoch 21/50
# 9576523/9576523 [==============================] - 164s 17us/sample - loss: 4.7798 - val_loss: 4.7829
# Epoch 22/50
# 9576523/9576523 [==============================] - 165s 17us/sample - loss: 4.7798 - val_loss: 4.7829
# Epoch 23/50
# 9576523/9576523 [==============================] - 164s 17us/sample - loss: 4.7798 - val_loss: 4.7829
# Epoch 24/50
# 9576523/9576523 [==============================] - 164s 17us/sample - loss: 4.7798 - val_loss: 4.7829
# Epoch 25/50
# 9576523/9576523 [==============================] - 164s 17us/sample - loss: 4.7798 - val_loss: 4.7829
# Epoch 26/50
# 9576523/9576523 [==============================] - 164s 17us/sample - loss: 4.7798 - val_loss: 4.7829
# Epoch 27/50
# 9576523/9576523 [==============================] - 165s 17us/sample - loss: 4.7798 - val_loss: 4.7829
# Epoch 28/50
# 9576523/9576523 [==============================] - 165s 17us/sample - loss: 4.7798 - val_loss: 4.7829
# Epoch 29/50
# 9576523/9576523 [==============================] - 164s 17us/sample - loss: 4.7798 - val_loss: 4.7829
# Epoch 30/50
# 9576523/9576523 [==============================] - 164s 17us/sample - loss: 4.7798 - val_loss: 4.7829
# Epoch 31/50
# 9576523/9576523 [==============================] - 164s 17us/sample - loss: 4.7798 - val_loss: 4.7829
# Epoch 32/50
# 9576523/9576523 [==============================] - 165s 17us/sample - loss: 4.7798 - val_loss: 4.7829
# Epoch 33/50
# 9576523/9576523 [==============================] - 165s 17us/sample - loss: 4.7798 - val_loss: 4.7829
# Epoch 34/50
# 9576523/9576523 [==============================] - 165s 17us/sample - loss: 4.7798 - val_loss: 4.7829
# Epoch 35/50
# 9576523/9576523 [==============================] - 165s 17us/sample - loss: 4.7798 - val_loss: 4.7829
# Epoch 36/50
# 9576523/9576523 [==============================] - 165s 17us/sample - loss: 4.7798 - val_loss: 4.7829
# Epoch 37/50
# 9576523/9576523 [==============================] - 164s 17us/sample - loss: 4.7798 - val_loss: 4.7829
# Epoch 38/50
# 9576523/9576523 [==============================] - 164s 17us/sample - loss: 4.7798 - val_loss: 4.7829
# Epoch 39/50
# 9576523/9576523 [==============================] - 164s 17us/sample - loss: 4.7798 - val_loss: 4.7829
# Epoch 40/50
# 9576523/9576523 [==============================] - 167s 17us/sample - loss: 4.7798 - val_loss: 4.7829
# Epoch 41/50
# 9576523/9576523 [==============================] - 165s 17us/sample - loss: 4.7798 - val_loss: 4.7829
# Epoch 42/50
# 9576523/9576523 [==============================] - 165s 17us/sample - loss: 4.7798 - val_loss: 4.7829
# Epoch 43/50
# 9576523/9576523 [==============================] - 164s 17us/sample - loss: 4.7798 - val_loss: 4.7829
# Epoch 44/50
# 9576523/9576523 [==============================] - 165s 17us/sample - loss: 4.7798 - val_loss: 4.7829
# Epoch 45/50
# 9576523/9576523 [==============================] - 164s 17us/sample - loss: 4.7798 - val_loss: 4.7829
# Epoch 46/50
# 9576523/9576523 [==============================] - 165s 17us/sample - loss: 4.7798 - val_loss: 4.7829
# Epoch 47/50
# 9576523/9576523 [==============================] - 164s 17us/sample - loss: 4.7798 - val_loss: 4.7829
# Epoch 48/50
# 9576523/9576523 [==============================] - 164s 17us/sample - loss: 4.7798 - val_loss: 4.7829
# Epoch 49/50
# 9576523/9576523 [==============================] - 164s 17us/sample - loss: 4.7798 - val_loss: 4.7829
# Epoch 50/50
# 9576523/9576523 [==============================] - 164s 17us/sample - loss: 4.7798 - val_loss: 4.7829

# %%
y_pred_nn = model_2.predict(x_test)
y_pred_nn[y_pred_nn < 0] = 0

# %%
nn_rmsle = rmsle(list(y_test), list(y_pred_nn))

# %%
print('LSTM RMSLE Score is {}'.format(nn_rmsle))
# Out:
# LSTM RMSLE Score is 2.1839909176624137

# %%
# 2.18489
